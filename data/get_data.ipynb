# %% [markdown]
# # Собираем датасет

# %% [markdown]
# ## Установка нужных библиотек

# %%
# !pip install wandb
# !pip install stable_baselines3
# !pip install shimmy
# !pip install gymnasium stable-baselines3
# !pip install gym
# Out:
# Collecting wandb
#   Downloading wandb-0.17.5-py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb) (8.1.7)
# Collecting docker-pycreds>=0.4.0 (from wandb)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting gitpython!=3.1.29,>=1.0.0 (from wandb)
#   Downloading GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.10/dist-packages (from wandb) (4.2.2)
# Requirement already satisfied: protobuf!=4.21.0,<6,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (3.20.3)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from wandb) (6.0.1)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (2.31.0)
# Collecting sentry-sdk>=1.0.0 (from wandb)
#   Downloading sentry_sdk-2.12.0-py2.py3-none-any.whl.metadata (9.8 kB)
# Collecting setproctitle (from wandb)
#   Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.9 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb) (71.0.4)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.29,>=1.0.0->wandb)
#   Downloading gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (2024.7.4)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb)
#   Downloading smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Downloading wandb-0.17.5-py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 52.7 MB/s eta 0:00:00
# Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 16.0 MB/s eta 0:00:00
# Downloading sentry_sdk-2.12.0-py2.py3-none-any.whl (301 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 kB 21.5 MB/s eta 0:00:00
# Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 4.3 MB/s eta 0:00:00
# Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: smmap, setproctitle, sentry-sdk, docker-pycreds, gitdb, gitpython, wandb
# Successfully installed docker-pycreds-0.4.0 gitdb-4.0.11 gitpython-3.1.43 sentry-sdk-2.12.0 setproctitle-1.3.3 smmap-5.0.1 wandb-0.17.5
# Collecting stable_baselines3
#   Downloading stable_baselines3-2.3.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting gymnasium<0.30,>=0.28.1 (from stable_baselines3)
#   Downloading gymnasium-0.29.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (1.26.4)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (2.3.1+cu121)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (2.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (2.1.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (3.7.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3) (4.12.2)
# Collecting farama-notifications>=0.0.1 (from gymnasium<0.30,>=0.28.1->stable_baselines3)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (3.15.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (2024.6.1)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.13->stable_baselines3)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.13->stable_baselines3)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.13->stable_baselines3)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.13->stable_baselines3)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.13->stable_baselines3)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.13->stable_baselines3)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.13->stable_baselines3)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.13->stable_baselines3)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.13->stable_baselines3)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.13->stable_baselines3)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.13->stable_baselines3)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (2.3.1)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13->stable_baselines3)
#   Downloading nvidia_nvjitlink_cu12-12.6.20-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable_baselines3) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable_baselines3) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->stable_baselines3) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13->stable_baselines3) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable_baselines3) (1.3.0)
# Downloading stable_baselines3-2.3.2-py3-none-any.whl (182 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.3/182.3 kB 2.3 MB/s eta 0:00:00
# Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 33.1 MB/s eta 0:00:00
# Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Downloading nvidia_nvjitlink_cu12-12.6.20-py3-none-manylinux2014_x86_64.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 36.5 MB/s eta 0:00:00
# Installing collected packages: farama-notifications, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, gymnasium, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, stable_baselines3
# Successfully installed farama-notifications-0.0.4 gymnasium-0.29.1 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.6.20 nvidia-nvtx-cu12-12.1.105 stable_baselines3-2.3.2
# Collecting shimmy
#   Downloading Shimmy-2.0.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from shimmy) (1.26.4)
# Collecting gymnasium>=1.0.0a1 (from shimmy)
#   Downloading gymnasium-1.0.0a2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=1.0.0a1->shimmy) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=1.0.0a1->shimmy) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=1.0.0a1->shimmy) (0.0.4)
# Downloading Shimmy-2.0.0-py3-none-any.whl (30 kB)
# Downloading gymnasium-1.0.0a2-py3-none-any.whl (954 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.3/954.3 kB 3.2 MB/s eta 0:00:00
# Installing collected packages: gymnasium, shimmy
#   Attempting uninstall: gymnasium
#     Found existing installation: gymnasium 0.29.1
#     Uninstalling gymnasium-0.29.1:
#       Successfully uninstalled gymnasium-0.29.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# stable-baselines3 2.3.2 requires gymnasium<0.30,>=0.28.1, but you have gymnasium 1.0.0a2 which is incompatible.
# Successfully installed gymnasium-1.0.0a2 shimmy-2.0.0
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.10/dist-packages (1.0.0a2)
# Requirement already satisfied: stable-baselines3 in /usr/local/lib/python3.10/dist-packages (2.3.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (0.0.4)
# Collecting gymnasium
#   Using cached gymnasium-0.29.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (2.3.1+cu121)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (2.1.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (3.7.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (3.15.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (2.3.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13->stable-baselines3) (12.6.20)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13->stable-baselines3) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable-baselines3) (1.3.0)
# Using cached gymnasium-0.29.1-py3-none-any.whl (953 kB)
# Installing collected packages: gymnasium
#   Attempting uninstall: gymnasium
#     Found existing installation: gymnasium 1.0.0a2
#     Uninstalling gymnasium-1.0.0a2:
#       Successfully uninstalled gymnasium-1.0.0a2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# shimmy 2.0.0 requires gymnasium>=1.0.0a1, but you have gymnasium 0.29.1 which is incompatible.
# Successfully installed gymnasium-0.29.1
# Requirement already satisfied: gym in /usr/local/lib/python3.10/dist-packages (0.25.2)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from gym) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym) (0.0.8)

# %% [markdown]
# ## Вход в учетную запись Weights&Biases

# %%
# !wandb login
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %% [markdown]
# ##Импорт нужных модулей

# %%
import torch
from torch import nn
import torch.nn.functional as F
import json
import pickle
import gym
import numpy as np
from stable_baselines3.common.callbacks import BaseCallback
import wandb
from stable_baselines3 import A2C
import envs
# Out:
# /usr/local/lib/python3.10/dist-packages/wandb/analytics/sentry.py:90: SentryHubDeprecationWarning: `sentry_sdk.Hub` is deprecated and will be removed in a future major release. Please consult our 1.x to 2.x migration guide for details on how to migrate `Hub` usage to the new API: https://docs.sentry.io/platforms/python/migration/1.x-to-2.x
#   self.hub = sentry_sdk.Hub(client)

# %% [markdown]
# ## Теперь нужно описать, как мы будем сохранять траектории

# %%
class SaveTrajCallBack(BaseCallback):
    """
    Класс для сохранения и логирования траекторий
    """
    def __init__(self, verbose=0, env=None, lifetime_idx=None, log=False, log_interval=1000):
        """
        Инициализация callback

        :param verbose: Уровень verbose
        :param env: Среда, в которой происходит обучение
        :param lifetime_idx: Индекс жизненного цикла
        :param log: Флаг, указывающий, нужно ли логировать данные с использованием wandb
        :param log_interval: Интервал для логирования данных
        """
        super().__init__(verbose)
        self.env = env
        self.lifetime_idx = lifetime_idx
        self.log = log
        self.log_interval = log_interval

        self.trajectories = []

    def _on_step(self) -> bool:
        """
        Метод, вызываемый на каждом шаге обучения. Собирает текущие состояние, действие и награду,
        а также time step и добавляет в список траекторий.

        :return: True, если обучение должно продолжаться.
        """
        episode_length = self.env.episode_length
        learning_step = self.num_timesteps - 1

        state = self.locals.get('obs_tensor')[0].tolist()
        action = self.locals.get('actions')[0].tolist()
        reward = self.locals.get('rewards')[0].tolist()

        timestep = learning_step % episode_length

        self.trajectories.append((state, action, reward, timestep))

        log_interval = self.log_interval
        if (learning_step + 1) % log_interval == 0:
            mean_reward = np.mean([t[2] for t in self.trajectories[-log_interval:]])
            print(f'Шаг времени: {self.num_timesteps}, Средняя награда: {mean_reward}')

            if self.log:
                wandb.log({'mean_reward': mean_reward})

        return True
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
def collect_lifetimes(
        env_id: str,
        lifetime_num: int = 10,
        lifetime_start_idx: int = 0,
        total_steps: int = 10000,
        output_prefix: str = None,
        alg_config: str = None,
        log: bool = False,
) -> None:
    """
    Собирает lifetimes (жизненные циклы), используя алгоритм A2C

    Args:
        env_id: ID используемой среды Gym
        lifetime_num: Количество жизненных циклов, которые нужно сохранить
        total_steps: Общее количество шагов обучения

    Returns:
        Список жизненных циклов, каждый из которйо сконкатенирован в лист траекторий:
        [(o0^0, a0^0, r0^0, t0^0), (o1^0, a1^0, r1^0, t1^0), ..., , (oT^0, aT^0, rT^0, tT^0),
         (o0^1, a0^1, r0^1, t0^1), (o1^1, a1^1, r1^1, t1^1), ..., (oT^1, aT^1, rT^1, t1^1),
         ...]
        _t --  timestep, ^i -- индекс траектории
    """
    agent_config = json.load(open(alg_config, 'r'))

    if log:
        wandb.init(
            project='alg-distill',
            name=env_id + '-collect',
            monitor_gym=True,
            config={
                'env_id': env_id,
                'lifetime_num': lifetime_num,
                'total_steps': total_steps,
                **agent_config,
            }
        )

    for lifetime_idx in range(lifetime_start_idx, lifetime_num):
        print(f'Запуск lifetime {lifetime_idx}...')

        env = gym.make(env_id)

        alg = A2C(env=env, **agent_config)
        callback = SaveTrajCallBack(env=env, lifetime_idx=lifetime_idx, log=log)

        alg.learn(total_timesteps=total_steps, callback=callback)

        if output_prefix:
            pickle.dump(callback.trajectories, open(f"{output_prefix}_{lifetime_idx}.pkl", 'wb'))

# %% [markdown]
# ###Функция для нахождения конфига DarkRoom

# %%
def find_config_file(env_id: str, alg: str):
    if env_id.startswith('DarkRoom'):
        return f"configs/DarkRoom-{alg}.json"
    else:
        raise ValueError(f"Неизвестная среда или алгоритм: {env_id, alg}")

# %% [markdown]
# ## Собираем lifetimes

# %%
alg_config = find_config_file('DarkRoom-v0', 'a2c')

print(f'alg_config: {alg_config}')

collect_lifetimes(
    env_id='DarkRoom-v0',
    lifetime_num=2000,
    lifetime_start_idx=1800,
    total_steps=20000,
    output_prefix='darkroom_normal',
    alg_config=alg_config,
    log=True,
)
# Out:
# alg_config: configs/DarkRoom-a2c.json
# Tracking run with wandb version 0.17.5
# Run data is saved locally in <code>/content/wandb/run-20240802_093036-muy0qsju</code>
# Syncing run <strong><a href='https://wandb.ai/innavakulenko-none/alg-distill/runs/muy0qsju' target="_blank">DarkRoom-v0-collect</a></strong> to <a href='https://wandb.ai/innavakulenko-none/alg-distill' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/innavakulenko-none/alg-distill' target="_blank">https://wandb.ai/innavakulenko-none/alg-distill</a>
#  View run at <a href='https://wandb.ai/innavakulenko-none/alg-distill/runs/muy0qsju' target="_blank">https://wandb.ai/innavakulenko-none/alg-distill/runs/muy0qsju</a>
# Выходные данные были обрезаны до нескольких последних строк (5000).
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 1.05     |
# | time/                 |          |
# |    fps                | 841      |
# |    iterations         | 100      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.54    |
# |    explained_variance | 0.00327  |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 99       |
# |    policy_loss        | 0.795    |
# |    value_loss         | 0.999    |
# ------------------------------------
# Шаг времени: 11000, Средняя награда: 0.042
# Шаг времени: 12000, Средняя награда: 0.056
# Шаг времени: 13000, Средняя награда: 0.061
# Шаг времени: 14000, Средняя награда: 0.04
# Шаг времени: 15000, Средняя награда: 0.064
# Шаг времени: 16000, Средняя награда: 0.045
# Шаг времени: 17000, Средняя награда: 0.075
# Шаг времени: 18000, Средняя награда: 0.06
# Шаг времени: 19000, Средняя награда: 0.049
# Шаг времени: 20000, Средняя награда: 0.055
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 1.04     |
# | time/                 |          |
# |    fps                | 826      |
# |    iterations         | 200      |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -1.51    |
# |    explained_variance | -0.0226  |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 199      |
# |    policy_loss        | 0.0276   |
# |    value_loss         | 0.46     |
# ------------------------------------
# Запуск lifetime 1916...
# Goal position: [1, 8]
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Шаг времени: 1000, Средняя награда: 0.002
# Шаг времени: 2000, Средняя награда: 0.023
# Шаг времени: 3000, Средняя награда: 0.036
# Шаг времени: 4000, Средняя награда: 0.081
# Шаг времени: 5000, Средняя награда: 0.092
# Шаг времени: 6000, Средняя награда: 0.092
# Шаг времени: 7000, Средняя награда: 0.114
# Шаг времени: 8000, Средняя награда: 0.1
# Шаг времени: 9000, Средняя награда: 0.1
# Шаг времени: 10000, Средняя награда: 0.098
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 1.98     |
# | time/                 |          |
# |    fps                | 818      |
# |    iterations         | 100      |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.3     |
# |    explained_variance | 0.101    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 99       |
# |    policy_loss        | -0.465   |
# |    value_loss         | 0.521    |
# ------------------------------------
# Шаг времени: 11000, Средняя награда: 0.111
# Шаг времени: 12000, Средняя награда: 0.132
# Шаг времени: 13000, Средняя награда: 0.12
# Шаг времени: 14000, Средняя награда: 0.132
# Шаг времени: 15000, Средняя награда: 0.131
# Шаг времени: 16000, Средняя награда: 0.14
# Шаг времени: 17000, Средняя награда: 0.111
# Шаг времени: 18000, Средняя награда: 0.122
# Шаг времени: 19000, Средняя награда: 0.123
# Шаг времени: 20000, Средняя награда: 0.121
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 2.44     |
# | time/                 |          |
# |    fps                | 803      |
# |    iterations         | 200      |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -1.13    |
# |    explained_variance | 0.165    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 199      |
# |    policy_loss        | -0.545   |
# |    value_loss         | 0.785    |
# ------------------------------------
# Запуск lifetime 1917...
# Goal position: [3, 6]
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Шаг времени: 1000, Средняя награда: 0.02
# Шаг времени: 2000, Средняя награда: 0.023
# Шаг времени: 3000, Средняя награда: 0.027
# Шаг времени: 4000, Средняя награда: 0.03
# Шаг времени: 5000, Средняя награда: 0.037
# Шаг времени: 6000, Средняя награда: 0.036
# Шаг времени: 7000, Средняя награда: 0.04
# Шаг времени: 8000, Средняя награда: 0.059
# Шаг времени: 9000, Средняя награда: 0.044
# Шаг времени: 10000, Средняя награда: 0.051
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 0.95     |
# | time/                 |          |
# |    fps                | 823      |
# |    iterations         | 100      |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.55    |
# |    explained_variance | 0.149    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 99       |
# |    policy_loss        | -0.27    |
# |    value_loss         | 0.245    |
# ------------------------------------
# Шаг времени: 11000, Средняя награда: 0.046
# Шаг времени: 12000, Средняя награда: 0.048
# Шаг времени: 13000, Средняя награда: 0.043
# Шаг времени: 14000, Средняя награда: 0.077
# Шаг времени: 15000, Средняя награда: 0.052
# Шаг времени: 16000, Средняя награда: 0.051
# Шаг времени: 17000, Средняя награда: 0.04
# Шаг времени: 18000, Средняя награда: 0.045
# Шаг времени: 19000, Средняя награда: 0.065
# Шаг времени: 20000, Средняя награда: 0.062
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 1.27     |
# | time/                 |          |
# |    fps                | 819      |
# |    iterations         | 200      |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -1.55    |
# |    explained_variance | 0.0285   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 199      |
# |    policy_loss        | -0.0743  |
# |    value_loss         | 0.165    |
# ------------------------------------
# Запуск lifetime 1918...
# Goal position: [2, 4]
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Шаг времени: 1000, Средняя награда: 0.024
# Шаг времени: 2000, Средняя награда: 0.046
# Шаг времени: 3000, Средняя награда: 0.039
# Шаг времени: 4000, Средняя награда: 0.065
# Шаг времени: 5000, Средняя награда: 0.066
# Шаг времени: 6000, Средняя награда: 0.047
# Шаг времени: 7000, Средняя награда: 0.042
# Шаг времени: 8000, Средняя награда: 0.073
# Шаг времени: 9000, Средняя награда: 0.061
# Шаг времени: 10000, Средняя награда: 0.076
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 1.37     |
# | time/                 |          |
# |    fps                | 812      |
# |    iterations         | 100      |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.51    |
# |    explained_variance | 0.176    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 99       |
# |    policy_loss        | -0.722   |
# |    value_loss         | 0.431    |
# ------------------------------------
# Шаг времени: 11000, Средняя награда: 0.069
# Шаг времени: 12000, Средняя награда: 0.101
# Шаг времени: 13000, Средняя награда: 0.089
# Шаг времени: 14000, Средняя награда: 0.092
# Шаг времени: 15000, Средняя награда: 0.126
# Шаг времени: 16000, Средняя награда: 0.085
# Шаг времени: 17000, Средняя награда: 0.157
# Шаг времени: 18000, Средняя награда: 0.155
# Шаг времени: 19000, Средняя награда: 0.128
# Шаг времени: 20000, Средняя награда: 0.139
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 2.67     |
# | time/                 |          |
# |    fps                | 814      |
# |    iterations         | 200      |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -1.35    |
# |    explained_variance | 0.37     |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 199      |
# |    policy_loss        | -0.703   |
# |    value_loss         | 0.602    |
# ------------------------------------
# Запуск lifetime 1919...
# Goal position: [2, 2]
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Шаг времени: 1000, Средняя награда: 0.014
# Шаг времени: 2000, Средняя награда: 0.014
# Шаг времени: 3000, Средняя награда: 0.02
# Шаг времени: 4000, Средняя награда: 0.021
# Шаг времени: 5000, Средняя награда: 0.027
# Шаг времени: 6000, Средняя награда: 0.034
# Шаг времени: 7000, Средняя награда: 0.045
# Шаг времени: 8000, Средняя награда: 0.045
# Шаг времени: 9000, Средняя награда: 0.036
# Шаг времени: 10000, Средняя награда: 0.053
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 0.89     |
# | time/                 |          |
# |    fps                | 826      |
# |    iterations         | 100      |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.51    |
# |    explained_variance | 0.065    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 99       |
# |    policy_loss        | 0.101    |
# |    value_loss         | 0.976    |
# ------------------------------------
# Шаг времени: 11000, Средняя награда: 0.06
# Шаг времени: 12000, Средняя награда: 0.055
# Шаг времени: 13000, Средняя награда: 0.051
# Шаг времени: 14000, Средняя награда: 0.051
# Шаг времени: 15000, Средняя награда: 0.071
# Шаг времени: 16000, Средняя награда: 0.075
# Шаг времени: 17000, Средняя награда: 0.061
# Шаг времени: 18000, Средняя награда: 0.069
# Шаг времени: 19000, Средняя награда: 0.08
# Шаг времени: 20000, Средняя награда: 0.098
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 1.78     |
# | time/                 |          |
# |    fps                | 847      |
# |    iterations         | 200      |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -1.48    |
# |    explained_variance | 0.181    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 199      |
# |    policy_loss        | -0.00318 |
# |    value_loss         | 0.916    |
# ------------------------------------
# Запуск lifetime 1920...
# Goal position: [1, 7]
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Шаг времени: 1000, Средняя награда: 0.012
# Шаг времени: 2000, Средняя награда: 0.014
# Шаг времени: 3000, Средняя награда: 0.023
# Шаг времени: 4000, Средняя награда: 0.028
# Шаг времени: 5000, Средняя награда: 0.048
# Шаг времени: 6000, Средняя награда: 0.031
# Шаг времени: 7000, Средняя награда: 0.045
# Шаг времени: 8000, Средняя награда: 0.037
# Шаг времени: 9000, Средняя награда: 0.036
# Шаг времени: 10000, Средняя награда: 0.047
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 0.83     |
# | time/                 |          |
# |    fps                | 840      |
# |    iterations         | 100      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.48    |
# |    explained_variance | 0.146    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 99       |
# |    policy_loss        | -0.122   |
# |    value_loss         | 0.129    |
# ------------------------------------
# Шаг времени: 11000, Средняя награда: 0.045
# Шаг времени: 12000, Средняя награда: 0.042
# Шаг времени: 13000, Средняя награда: 0.042
# Шаг времени: 14000, Средняя награда: 0.037
# Шаг времени: 15000, Средняя награда: 0.04
# Шаг времени: 16000, Средняя награда: 0.045
# Шаг времени: 17000, Средняя награда: 0.039
# Шаг времени: 18000, Средняя награда: 0.047
# Шаг времени: 19000, Средняя награда: 0.063
# Шаг времени: 20000, Средняя награда: 0.053
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 1.16     |
# | time/                 |          |
# |    fps                | 828      |
# |    iterations         | 200      |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -1.44    |
# |    explained_variance | 0.0508   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 199      |
# |    policy_loss        | 0.728    |
# |    value_loss         | 0.83     |
# ------------------------------------
# Запуск lifetime 1921...
# Goal position: [3, 8]
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Шаг времени: 1000, Средняя награда: 0.006
# Шаг времени: 2000, Средняя награда: 0.018
# Шаг времени: 3000, Средняя награда: 0.033
# Шаг времени: 4000, Средняя награда: 0.025
# Шаг времени: 5000, Средняя награда: 0.074
# Шаг времени: 6000, Средняя награда: 0.073
# Шаг времени: 7000, Средняя награда: 0.173
# Шаг времени: 8000, Средняя награда: 0.167
# Шаг времени: 9000, Средняя награда: 0.148
# Шаг времени: 10000, Средняя награда: 0.165
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 3.13     |
# | time/                 |          |
# |    fps                | 795      |
# |    iterations         | 100      |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.12    |
# |    explained_variance | 0.0271   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 99       |
# |    policy_loss        | 0.449    |
# |    value_loss         | 2.87     |
# ------------------------------------
# Шаг времени: 11000, Средняя награда: 0.151
# Шаг времени: 12000, Средняя награда: 0.165
# Шаг времени: 13000, Средняя награда: 0.158
# Шаг времени: 14000, Средняя награда: 0.1
# Шаг времени: 15000, Средняя награда: 0.16
# Шаг времени: 16000, Средняя награда: 0.136
# Шаг времени: 17000, Средняя награда: 0.218
# Шаг времени: 18000, Средняя награда: 0.212
# Шаг времени: 19000, Средняя награда: 0.206
# Шаг времени: 20000, Средняя награда: 0.151
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 3.57     |
# | time/                 |          |
# |    fps                | 791      |
# |    iterations         | 200      |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.886   |
# |    explained_variance | 0.22     |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 199      |
# |    policy_loss        | -0.806   |
# |    value_loss         | 2.35     |
# ------------------------------------
# Запуск lifetime 1922...
# Goal position: [1, 6]
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Шаг времени: 1000, Средняя награда: 0.013
# Шаг времени: 2000, Средняя награда: 0.029
# Шаг времени: 3000, Средняя награда: 0.019
# Шаг времени: 4000, Средняя награда: 0.033
# Шаг времени: 5000, Средняя награда: 0.026
# Шаг времени: 6000, Средняя награда: 0.032
# Шаг времени: 7000, Средняя награда: 0.049
# Шаг времени: 8000, Средняя награда: 0.041
# Шаг времени: 9000, Средняя награда: 0.037
# Шаг времени: 10000, Средняя награда: 0.042
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 0.79     |
# | time/                 |          |
# |    fps                | 819      |
# |    iterations         | 100      |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.48    |
# |    explained_variance | 0.149    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 99       |
# |    policy_loss        | 0.174    |
# |    value_loss         | 0.388    |
# ------------------------------------
# Шаг времени: 11000, Средняя награда: 0.036
# Шаг времени: 12000, Средняя награда: 0.036
# Шаг времени: 13000, Средняя награда: 0.058
# Шаг времени: 14000, Средняя награда: 0.041
# Шаг времени: 15000, Средняя награда: 0.061
# Шаг времени: 16000, Средняя награда: 0.074
# Шаг времени: 17000, Средняя награда: 0.038
# Шаг времени: 18000, Средняя награда: 0.055
# Шаг времени: 19000, Средняя награда: 0.049
# Шаг времени: 20000, Средняя награда: 0.073
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 1.22     |
# | time/                 |          |
# |    fps                | 825      |
# |    iterations         | 200      |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -1.49    |
# |    explained_variance | 0.202    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 199      |
# |    policy_loss        | 0.404    |
# |    value_loss         | 0.861    |
# ------------------------------------
# Запуск lifetime 1923...
# Goal position: [1, 0]
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Шаг времени: 1000, Средняя награда: 0.003
# Шаг времени: 2000, Средняя награда: 0.002
# Шаг времени: 3000, Средняя награда: 0.007
# Шаг времени: 4000, Средняя награда: 0.0
# Шаг времени: 5000, Средняя награда: 0.004
# Шаг времени: 6000, Средняя награда: 0.005
# Шаг времени: 7000, Средняя награда: 0.004
# Шаг времени: 8000, Средняя награда: 0.007
# Шаг времени: 9000, Средняя награда: 0.012
# Шаг времени: 10000, Средняя награда: 0.006
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 0.18     |
# | time/                 |          |
# |    fps                | 819      |
# |    iterations         | 100      |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.57    |
# |    explained_variance | 0.134    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 99       |
# |    policy_loss        | -0.0291  |
# |    value_loss         | 0.0591   |
# ------------------------------------
# Шаг времени: 11000, Средняя награда: 0.025
# Шаг времени: 12000, Средняя награда: 0.067
# Шаг времени: 13000, Средняя награда: 0.07
# Шаг времени: 14000, Средняя награда: 0.093
# Шаг времени: 15000, Средняя награда: 0.106
# Шаг времени: 16000, Средняя награда: 0.108
# Шаг времени: 17000, Средняя награда: 0.159
# Шаг времени: 18000, Средняя награда: 0.16
# Шаг времени: 19000, Средняя награда: 0.136
# Шаг времени: 20000, Средняя награда: 0.154
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 2.9      |
# | time/                 |          |
# |    fps                | 824      |
# |    iterations         | 200      |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -1.27    |
# |    explained_variance | 0.249    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 199      |
# |    policy_loss        | 0.549    |
# |    value_loss         | 2.32     |
# ------------------------------------
# Запуск lifetime 1924...
# Goal position: [7, 4]
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Шаг времени: 1000, Средняя награда: 0.005
# Шаг времени: 2000, Средняя награда: 0.021
# Шаг времени: 3000, Средняя награда: 0.048
# Шаг времени: 4000, Средняя награда: 0.048
# Шаг времени: 5000, Средняя награда: 0.055
# Шаг времени: 6000, Средняя награда: 0.066
# Шаг времени: 7000, Средняя награда: 0.054
# Шаг времени: 8000, Средняя награда: 0.056
# Шаг времени: 9000, Средняя награда: 0.076
# Шаг времени: 10000, Средняя награда: 0.069
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 1.45     |
# | time/                 |          |
# |    fps                | 863      |
# |    iterations         | 100      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.28    |
# |    explained_variance | 0.0115   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 99       |
# |    policy_loss        | 0.384    |
# |    value_loss         | 2.05     |
# ------------------------------------
# Шаг времени: 11000, Средняя награда: 0.058
# Шаг времени: 12000, Средняя награда: 0.103
# Шаг времени: 13000, Средняя награда: 0.07
# Шаг времени: 14000, Средняя награда: 0.076
# Шаг времени: 15000, Средняя награда: 0.099
# Шаг времени: 16000, Средняя награда: 0.106
# Шаг времени: 17000, Средняя награда: 0.118
# Шаг времени: 18000, Средняя награда: 0.111
# Шаг времени: 19000, Средняя награда: 0.125
# Шаг времени: 20000, Средняя награда: 0.111
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 2.36     |
# | time/                 |          |
# |    fps                | 862      |
# |    iterations         | 200      |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -1.14    |
# |    explained_variance | 0.0264   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 199      |
# |    policy_loss        | 0.336    |
# |    value_loss         | 1.22     |
# ------------------------------------
# Запуск lifetime 1925...
# Goal position: [7, 6]
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Шаг времени: 1000, Средняя награда: 0.005
# Шаг времени: 2000, Средняя награда: 0.011
# Шаг времени: 3000, Средняя награда: 0.02
# Шаг времени: 4000, Средняя награда: 0.021
# Шаг времени: 5000, Средняя награда: 0.022
# Шаг времени: 6000, Средняя награда: 0.029
# Шаг времени: 7000, Средняя награда: 0.036
# Шаг времени: 8000, Средняя награда: 0.036
# Шаг времени: 9000, Средняя награда: 0.037
# Шаг времени: 10000, Средняя награда: 0.025
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 0.62     |
# | time/                 |          |
# |    fps                | 832      |
# |    iterations         | 100      |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.44    |
# |    explained_variance | 0.0649   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 99       |
# |    policy_loss        | 0.175    |
# |    value_loss         | 0.288    |
# ------------------------------------
# Шаг времени: 11000, Средняя награда: 0.036
# Шаг времени: 12000, Средняя награда: 0.028
# Шаг времени: 13000, Средняя награда: 0.038
# Шаг времени: 14000, Средняя награда: 0.035
# Шаг времени: 15000, Средняя награда: 0.047
# Шаг времени: 16000, Средняя награда: 0.026
# Шаг времени: 17000, Средняя награда: 0.037
# Шаг времени: 18000, Средняя награда: 0.042
# Шаг времени: 19000, Средняя награда: 0.054
# Шаг времени: 20000, Средняя награда: 0.05
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 1.04     |
# | time/                 |          |
# |    fps                | 829      |
# |    iterations         | 200      |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -1.42    |
# |    explained_variance | 0.233    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 199      |
# |    policy_loss        | -0.468   |
# |    value_loss         | 0.206    |
# ------------------------------------
# Запуск lifetime 1926...
# Goal position: [2, 5]
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Шаг времени: 1000, Средняя награда: 0.026
# Шаг времени: 2000, Средняя награда: 0.029
# Шаг времени: 3000, Средняя награда: 0.039
# Шаг времени: 4000, Средняя награда: 0.038
# Шаг времени: 5000, Средняя награда: 0.032
# Шаг времени: 6000, Средняя награда: 0.034
# Шаг времени: 7000, Средняя награда: 0.038
# Шаг времени: 8000, Средняя награда: 0.049
# Шаг времени: 9000, Средняя награда: 0.043
# Шаг времени: 10000, Средняя награда: 0.029
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 0.72     |
# | time/                 |          |
# |    fps                | 797      |
# |    iterations         | 100      |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.56    |
# |    explained_variance | 0.0405   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 99       |
# |    policy_loss        | 0.358    |
# |    value_loss         | 0.253    |
# ------------------------------------
# Шаг времени: 11000, Средняя награда: 0.054
# Шаг времени: 12000, Средняя награда: 0.058
# Шаг времени: 13000, Средняя награда: 0.07
# Шаг времени: 14000, Средняя награда: 0.053
# Шаг времени: 15000, Средняя награда: 0.072
# Шаг времени: 16000, Средняя награда: 0.058
# Шаг времени: 17000, Средняя награда: 0.06
# Шаг времени: 18000, Средняя награда: 0.055
# Шаг времени: 19000, Средняя награда: 0.084
# Шаг времени: 20000, Средняя награда: 0.087
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 1.71     |
# | time/                 |          |
# |    fps                | 810      |
# |    iterations         | 200      |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -1.48    |
# |    explained_variance | 0.0128   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 199      |
# |    policy_loss        | 0.53     |
# |    value_loss         | 1.38     |
# ------------------------------------
# Запуск lifetime 1927...
# Goal position: [0, 1]
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Шаг времени: 1000, Средняя награда: 0.0
# Шаг времени: 2000, Средняя награда: 0.0
# Шаг времени: 3000, Средняя награда: 0.0
# Шаг времени: 4000, Средняя награда: 0.01
# Шаг времени: 5000, Средняя награда: 0.01
# Шаг времени: 6000, Средняя награда: 0.015
# Шаг времени: 7000, Средняя награда: 0.004
# Шаг времени: 8000, Средняя награда: 0.019
# Шаг времени: 9000, Средняя награда: 0.035
# Шаг времени: 10000, Средняя награда: 0.038
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 0.73     |
# | time/                 |          |
# |    fps                | 833      |
# |    iterations         | 100      |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.51    |
# |    explained_variance | 0.0245   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 99       |
# |    policy_loss        | 0.83     |
# |    value_loss         | 1.13     |
# ------------------------------------
# Шаг времени: 11000, Средняя награда: 0.051
# Шаг времени: 12000, Средняя награда: 0.067
# Шаг времени: 13000, Средняя награда: 0.141
# Шаг времени: 14000, Средняя награда: 0.132
# Шаг времени: 15000, Средняя награда: 0.146
# Шаг времени: 16000, Средняя награда: 0.176
# Шаг времени: 17000, Средняя награда: 0.187
# Шаг времени: 18000, Средняя награда: 0.176
# Шаг времени: 19000, Средняя награда: 0.155
# Шаг времени: 20000, Средняя награда: 0.177
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 3.32     |
# | time/                 |          |
# |    fps                | 831      |
# |    iterations         | 200      |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -1.24    |
# |    explained_variance | 0.244    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 199      |
# |    policy_loss        | 0.467    |
# |    value_loss         | 2.79     |
# ------------------------------------
# Запуск lifetime 1928...
# Goal position: [1, 1]
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Шаг времени: 1000, Средняя награда: 0.004
# Шаг времени: 2000, Средняя награда: 0.001
# Шаг времени: 3000, Средняя награда: 0.005
# Шаг времени: 4000, Средняя награда: 0.007
# Шаг времени: 5000, Средняя награда: 0.012
# Шаг времени: 6000, Средняя награда: 0.028
# Шаг времени: 7000, Средняя награда: 0.038
# Шаг времени: 8000, Средняя награда: 0.051
# Шаг времени: 9000, Средняя награда: 0.044
# Шаг времени: 10000, Средняя награда: 0.057
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 1.01     |
# | time/                 |          |
# |    fps                | 840      |
# |    iterations         | 100      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.44    |
# |    explained_variance | -0.0234  |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 99       |
# |    policy_loss        | -0.561   |
# |    value_loss         | 0.207    |
# ------------------------------------
# Шаг времени: 11000, Средняя награда: 0.067
# Шаг времени: 12000, Средняя награда: 0.06
# Шаг времени: 13000, Средняя награда: 0.052
# Шаг времени: 14000, Средняя награда: 0.081
# Шаг времени: 15000, Средняя награда: 0.049
# Шаг времени: 16000, Средняя награда: 0.078
# Шаг времени: 17000, Средняя награда: 0.098
# Шаг времени: 18000, Средняя награда: 0.071
# Шаг времени: 19000, Средняя награда: 0.092
# Шаг времени: 20000, Средняя награда: 0.089
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 1.81     |
# | time/                 |          |
# |    fps                | 853      |
# |    iterations         | 200      |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -1.43    |
# |    explained_variance | 0.128    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 199      |
# |    policy_loss        | 1.11     |
# |    value_loss         | 1.3      |
# ------------------------------------
# Запуск lifetime 1929...
# Goal position: [7, 8]
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Шаг времени: 1000, Средняя награда: 0.003
# Шаг времени: 2000, Средняя награда: 0.004
# Шаг времени: 3000, Средняя награда: 0.004
# Шаг времени: 4000, Средняя награда: 0.024
# Шаг времени: 5000, Средняя награда: 0.044
# Шаг времени: 6000, Средняя награда: 0.071
# Шаг времени: 7000, Средняя награда: 0.064
# Шаг времени: 8000, Средняя награда: 0.114
# Шаг времени: 9000, Средняя награда: 0.106
# Шаг времени: 10000, Средняя награда: 0.104
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 2.1      |
# | time/                 |          |
# |    fps                | 844      |
# |    iterations         | 100      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.27    |
# |    explained_variance | 0.0298   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 99       |
# |    policy_loss        | -0.0667  |
# |    value_loss         | 2.66     |
# ------------------------------------
# Шаг времени: 11000, Средняя награда: 0.13
# Шаг времени: 12000, Средняя награда: 0.132
# Шаг времени: 13000, Средняя награда: 0.125
# Шаг времени: 14000, Средняя награда: 0.125
# Шаг времени: 15000, Средняя награда: 0.131
# Шаг времени: 16000, Средняя награда: 0.139
# Шаг времени: 17000, Средняя награда: 0.119
# Шаг времени: 18000, Средняя награда: 0.136
# Шаг времени: 19000, Средняя награда: 0.107
# Шаг времени: 20000, Средняя награда: 0.15
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 2.57     |
# | time/                 |          |
# |    fps                | 837      |
# |    iterations         | 200      |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -1.08    |
# |    explained_variance | 0.0367   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 199      |
# |    policy_loss        | -0.276   |
# |    value_loss         | 2.01     |
# ------------------------------------
# Запуск lifetime 1930...
# Goal position: [2, 6]
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Шаг времени: 1000, Средняя награда: 0.016
# Шаг времени: 2000, Средняя награда: 0.018
# Шаг времени: 3000, Средняя награда: 0.027
# Шаг времени: 4000, Средняя награда: 0.023
# Шаг времени: 5000, Средняя награда: 0.038
# Шаг времени: 6000, Средняя награда: 0.043
# Шаг времени: 7000, Средняя награда: 0.026
# Шаг времени: 8000, Средняя награда: 0.037
# Шаг времени: 9000, Средняя награда: 0.044
# Шаг времени: 10000, Средняя награда: 0.049
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 0.93     |
# | time/                 |          |
# |    fps                | 837      |
# |    iterations         | 100      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.49    |
# |    explained_variance | 0.0249   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 99       |
# |    policy_loss        | 0.416    |
# |    value_loss         | 0.58     |
# ------------------------------------
# Шаг времени: 11000, Средняя награда: 0.048
# Шаг времени: 12000, Средняя награда: 0.057
# Шаг времени: 13000, Средняя награда: 0.056
# Шаг времени: 14000, Средняя награда: 0.037
# Шаг времени: 15000, Средняя награда: 0.03
# Шаг времени: 16000, Средняя награда: 0.053
# Шаг времени: 17000, Средняя награда: 0.048
# Шаг времени: 18000, Средняя награда: 0.063
# Шаг времени: 19000, Средняя награда: 0.07
# Шаг времени: 20000, Средняя награда: 0.062
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 1.32     |
# | time/                 |          |
# |    fps                | 830      |
# |    iterations         | 200      |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -1.49    |
# |    explained_variance | -0.0457  |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 199      |
# |    policy_loss        | -0.232   |
# |    value_loss         | 0.172    |
# ------------------------------------
# Запуск lifetime 1931...
# Goal position: [8, 5]
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Шаг времени: 1000, Средняя награда: 0.007
# Шаг времени: 2000, Средняя награда: 0.007
# Шаг времени: 3000, Средняя награда: 0.017
# Шаг времени: 4000, Средняя награда: 0.049
# Шаг времени: 5000, Средняя награда: 0.085
# Шаг времени: 6000, Средняя награда: 0.099
# Шаг времени: 7000, Средняя награда: 0.167
# Шаг времени: 8000, Средняя награда: 0.129
# Шаг времени: 9000, Средняя награда: 0.148
# Шаг времени: 10000, Средняя награда: 0.2
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 3.48     |
# | time/                 |          |
# |    fps                | 804      |
# |    iterations         | 100      |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.1     |
# |    explained_variance | 0.137    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 99       |
# |    policy_loss        | 1.62     |
# |    value_loss         | 8.78     |
# ------------------------------------
# Шаг времени: 11000, Средняя награда: 0.219
# Шаг времени: 12000, Средняя награда: 0.2
# Шаг времени: 13000, Средняя награда: 0.248
# Шаг времени: 14000, Средняя награда: 0.234
# Шаг времени: 15000, Средняя награда: 0.244
# Шаг времени: 16000, Средняя награда: 0.193
# Шаг времени: 17000, Средняя награда: 0.254
# Шаг времени: 18000, Средняя награда: 0.192
# Шаг времени: 19000, Средняя награда: 0.256
# Шаг времени: 20000, Средняя награда: 0.246
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 5.02     |
# | time/                 |          |
# |    fps                | 812      |
# |    iterations         | 200      |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.815   |
# |    explained_variance | 0.053    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 199      |
# |    policy_loss        | -0.552   |
# |    value_loss         | 4.8      |
# ------------------------------------
# Запуск lifetime 1932...
# Goal position: [5, 0]
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Шаг времени: 1000, Средняя награда: 0.003
# Шаг времени: 2000, Средняя награда: 0.029
# Шаг времени: 3000, Средняя награда: 0.012
# Шаг времени: 4000, Средняя награда: 0.025
# Шаг времени: 5000, Средняя награда: 0.077
# Шаг времени: 6000, Средняя награда: 0.072
# Шаг времени: 7000, Средняя награда: 0.089
# Шаг времени: 8000, Средняя награда: 0.144
# Шаг времени: 9000, Средняя награда: 0.102
# Шаг времени: 10000, Средняя награда: 0.159
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 2.61     |
# | time/                 |          |
# |    fps                | 829      |
# |    iterations         | 100      |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.17    |
# |    explained_variance | 0.0762   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 99       |
# |    policy_loss        | 0.61     |
# |    value_loss         | 4.63     |
# ------------------------------------
# Шаг времени: 11000, Средняя награда: 0.136
# Шаг времени: 12000, Средняя награда: 0.125
# Шаг времени: 13000, Средняя награда: 0.174
# Шаг времени: 14000, Средняя награда: 0.17
# Шаг времени: 15000, Средняя награда: 0.155
# Шаг времени: 16000, Средняя награда: 0.221
# Шаг времени: 17000, Средняя награда: 0.182
# Шаг времени: 18000, Средняя награда: 0.19
# Шаг времени: 19000, Средняя награда: 0.162
# Шаг времени: 20000, Средняя награда: 0.157
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 3.19     |
# | time/                 |          |
# |    fps                | 838      |
# |    iterations         | 200      |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -1.03    |
# |    explained_variance | 0.0969   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 199      |
# |    policy_loss        | 0.527    |
# |    value_loss         | 6.14     |
# ------------------------------------
# Запуск lifetime 1933...
# Goal position: [7, 8]
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Шаг времени: 1000, Средняя награда: 0.0
# Шаг времени: 2000, Средняя награда: 0.001
# Шаг времени: 3000, Средняя награда: 0.005
# Шаг времени: 4000, Средняя награда: 0.016
# Шаг времени: 5000, Средняя награда: 0.028
# Шаг времени: 6000, Средняя награда: 0.024
# Шаг времени: 7000, Средняя награда: 0.068
# Шаг времени: 8000, Средняя награда: 0.089
# Шаг времени: 9000, Средняя награда: 0.073
# Шаг времени: 10000, Средняя награда: 0.103
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 1.76     |
# | time/                 |          |
# |    fps                | 863      |
# |    iterations         | 100      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.3     |
# |    explained_variance | 0.00641  |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 99       |
# |    policy_loss        | 0.825    |
# |    value_loss         | 3.93     |
# ------------------------------------
# Шаг времени: 11000, Средняя награда: 0.107
# Шаг времени: 12000, Средняя награда: 0.076
# Шаг времени: 13000, Средняя награда: 0.127
# Шаг времени: 14000, Средняя награда: 0.101
# Шаг времени: 15000, Средняя награда: 0.088
# Шаг времени: 16000, Средняя награда: 0.148
# Шаг времени: 17000, Средняя награда: 0.128
# Шаг времени: 18000, Средняя награда: 0.127
# Шаг времени: 19000, Средняя награда: 0.108
# Шаг времени: 20000, Средняя награда: 0.092
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 2        |
# | time/                 |          |
# |    fps                | 850      |
# |    iterations         | 200      |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -1.14    |
# |    explained_variance | 0.0903   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 199      |
# |    policy_loss        | -0.778   |
# |    value_loss         | 0.893    |
# ------------------------------------
# Запуск lifetime 1934...
# Goal position: [6, 8]
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Шаг времени: 1000, Средняя награда: 0.0
# Шаг времени: 2000, Средняя награда: 0.0
# Шаг времени: 3000, Средняя награда: 0.01
# Шаг времени: 4000, Средняя награда: 0.015
# Шаг времени: 5000, Средняя награда: 0.007
# Шаг времени: 6000, Средняя награда: 0.023
# Шаг времени: 7000, Средняя награда: 0.041
# Шаг времени: 8000, Средняя награда: 0.069
# Шаг времени: 9000, Средняя награда: 0.057
# Шаг времени: 10000, Средняя награда: 0.107
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 1.64     |
# | time/                 |          |
# |    fps                | 824      |
# |    iterations         | 100      |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.32    |
# |    explained_variance | -0.0231  |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 99       |
# |    policy_loss        | 0.75     |
# |    value_loss         | 2.61     |
# ------------------------------------
# Шаг времени: 11000, Средняя награда: 0.117
# Шаг времени: 12000, Средняя награда: 0.145
# Шаг времени: 13000, Средняя награда: 0.108
# Шаг времени: 14000, Средняя награда: 0.131
# Шаг времени: 15000, Средняя награда: 0.155
# Шаг времени: 16000, Средняя награда: 0.176
# Шаг времени: 17000, Средняя награда: 0.143
# Шаг времени: 18000, Средняя награда: 0.149
# Шаг времени: 19000, Средняя награда: 0.151
# Шаг времени: 20000, Средняя награда: 0.149
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 3        |
# | time/                 |          |
# |    fps                | 826      |
# |    iterations         | 200      |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -1.03    |
# |    explained_variance | -0.0197  |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 199      |
# |    policy_loss        | 0.426    |
# |    value_loss         | 4.81     |
# ------------------------------------
# Запуск lifetime 1935...
# Goal position: [1, 3]
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Шаг времени: 1000, Средняя награда: 0.007
# Шаг времени: 2000, Средняя награда: 0.019
# Шаг времени: 3000, Средняя награда: 0.044
# Шаг времени: 4000, Средняя награда: 0.035
# Шаг времени: 5000, Средняя награда: 0.045
# Шаг времени: 6000, Средняя награда: 0.043
# Шаг времени: 7000, Средняя награда: 0.042
# Шаг времени: 8000, Средняя награда: 0.044
# Шаг времени: 9000, Средняя награда: 0.047
# Шаг времени: 10000, Средняя награда: 0.064
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 1.11     |
# | time/                 |          |
# |    fps                | 821      |
# |    iterations         | 100      |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.47    |
# |    explained_variance | 0.141    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 99       |
# |    policy_loss        | 0.87     |
# |    value_loss         | 1.54     |
# ------------------------------------
# Шаг времени: 11000, Средняя награда: 0.047
# Шаг времени: 12000, Средняя награда: 0.071
# Шаг времени: 13000, Средняя награда: 0.07
# Шаг времени: 14000, Средняя награда: 0.069
# Шаг времени: 15000, Средняя награда: 0.068
# Шаг времени: 16000, Средняя награда: 0.071
# Шаг времени: 17000, Средняя награда: 0.057
# Шаг времени: 18000, Средняя награда: 0.09
# Шаг времени: 19000, Средняя награда: 0.093
# Шаг времени: 20000, Средняя награда: 0.066
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 1.59     |
# | time/                 |          |
# |    fps                | 806      |
# |    iterations         | 200      |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -1.46    |
# |    explained_variance | 0.201    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 199      |
# |    policy_loss        | 0.363    |
# |    value_loss         | 0.689    |
# ------------------------------------
# Запуск lifetime 1936...
# Goal position: [0, 3]
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Шаг времени: 1000, Средняя награда: 0.018
# Шаг времени: 2000, Средняя награда: 0.055
# Шаг времени: 3000, Средняя награда: 0.043
# Шаг времени: 4000, Средняя награда: 0.055
# Шаг времени: 5000, Средняя награда: 0.1
# Шаг времени: 6000, Средняя награда: 0.117
# Шаг времени: 7000, Средняя награда: 0.143
# Шаг времени: 8000, Средняя награда: 0.123
# Шаг времени: 9000, Средняя награда: 0.173
# ...
# |    entropy_loss       | -0.857   |
# |    explained_variance | -0.0127  |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 199      |
# |    policy_loss        | 0.431    |
# |    value_loss         | 4.97     |
# ------------------------------------
# Запуск lifetime 1993...
# Goal position: [6, 8]
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Шаг времени: 1000, Средняя награда: 0.0
# Шаг времени: 2000, Средняя награда: 0.011
# Шаг времени: 3000, Средняя награда: 0.011
# Шаг времени: 4000, Средняя награда: 0.033
# Шаг времени: 5000, Средняя награда: 0.06
# Шаг времени: 6000, Средняя награда: 0.071
# Шаг времени: 7000, Средняя награда: 0.072
# Шаг времени: 8000, Средняя награда: 0.095
# Шаг времени: 9000, Средняя награда: 0.129
# Шаг времени: 10000, Средняя награда: 0.133
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 2.62     |
# | time/                 |          |
# |    fps                | 787      |
# |    iterations         | 100      |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.18    |
# |    explained_variance | 0.0169   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 99       |
# |    policy_loss        | 0.719    |
# |    value_loss         | 7.53     |
# ------------------------------------
# Шаг времени: 11000, Средняя награда: 0.113
# Шаг времени: 12000, Средняя награда: 0.132
# Шаг времени: 13000, Средняя награда: 0.153
# Шаг времени: 14000, Средняя награда: 0.143
# Шаг времени: 15000, Средняя награда: 0.161
# Шаг времени: 16000, Средняя награда: 0.139
# Шаг времени: 17000, Средняя награда: 0.15
# Шаг времени: 18000, Средняя награда: 0.172
# Шаг времени: 19000, Средняя награда: 0.126
# Шаг времени: 20000, Средняя награда: 0.14
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 2.66     |
# | time/                 |          |
# |    fps                | 803      |
# |    iterations         | 200      |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -1       |
# |    explained_variance | 0.0499   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 199      |
# |    policy_loss        | 0.778    |
# |    value_loss         | 7.04     |
# ------------------------------------
# Запуск lifetime 1994...
# Goal position: [7, 2]
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Шаг времени: 1000, Средняя награда: 0.004
# Шаг времени: 2000, Средняя награда: 0.023
# Шаг времени: 3000, Средняя награда: 0.035
# Шаг времени: 4000, Средняя награда: 0.037
# Шаг времени: 5000, Средняя награда: 0.033
# Шаг времени: 6000, Средняя награда: 0.029
# Шаг времени: 7000, Средняя награда: 0.026
# Шаг времени: 8000, Средняя награда: 0.026
# Шаг времени: 9000, Средняя награда: 0.042
# Шаг времени: 10000, Средняя награда: 0.045
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 0.87     |
# | time/                 |          |
# |    fps                | 809      |
# |    iterations         | 100      |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.51    |
# |    explained_variance | 0.257    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 99       |
# |    policy_loss        | -0.131   |
# |    value_loss         | 0.196    |
# ------------------------------------
# Шаг времени: 11000, Средняя награда: 0.045
# Шаг времени: 12000, Средняя награда: 0.06
# Шаг времени: 13000, Средняя награда: 0.043
# Шаг времени: 14000, Средняя награда: 0.055
# Шаг времени: 15000, Средняя награда: 0.056
# Шаг времени: 16000, Средняя награда: 0.045
# Шаг времени: 17000, Средняя награда: 0.045
# Шаг времени: 18000, Средняя награда: 0.064
# Шаг времени: 19000, Средняя награда: 0.053
# Шаг времени: 20000, Средняя награда: 0.064
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 1.17     |
# | time/                 |          |
# |    fps                | 806      |
# |    iterations         | 200      |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -1.48    |
# |    explained_variance | 0.113    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 199      |
# |    policy_loss        | 1.16     |
# |    value_loss         | 1.47     |
# ------------------------------------
# Запуск lifetime 1995...
# Goal position: [4, 3]
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Шаг времени: 1000, Средняя награда: 0.068
# Шаг времени: 2000, Средняя награда: 0.07
# Шаг времени: 3000, Средняя награда: 0.074
# Шаг времени: 4000, Средняя награда: 0.074
# Шаг времени: 5000, Средняя награда: 0.077
# Шаг времени: 6000, Средняя награда: 0.074
# Шаг времени: 7000, Средняя награда: 0.098
# Шаг времени: 8000, Средняя награда: 0.099
# Шаг времени: 9000, Средняя награда: 0.097
# Шаг времени: 10000, Средняя награда: 0.147
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 2.44     |
# | time/                 |          |
# |    fps                | 813      |
# |    iterations         | 100      |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.44    |
# |    explained_variance | 0.118    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 99       |
# |    policy_loss        | -0.332   |
# |    value_loss         | 1.36     |
# ------------------------------------
# Шаг времени: 11000, Средняя награда: 0.161
# Шаг времени: 12000, Средняя награда: 0.147
# Шаг времени: 13000, Средняя награда: 0.137
# Шаг времени: 14000, Средняя награда: 0.131
# Шаг времени: 15000, Средняя награда: 0.122
# Шаг времени: 16000, Средняя награда: 0.149
# Шаг времени: 17000, Средняя награда: 0.209
# Шаг времени: 18000, Средняя награда: 0.193
# Шаг времени: 19000, Средняя награда: 0.236
# Шаг времени: 20000, Средняя награда: 0.231
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 4.67     |
# | time/                 |          |
# |    fps                | 817      |
# |    iterations         | 200      |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -1.23    |
# |    explained_variance | 0.112    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 199      |
# |    policy_loss        | -0.813   |
# |    value_loss         | 3.89     |
# ------------------------------------
# Запуск lifetime 1996...
# Goal position: [8, 0]
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Шаг времени: 1000, Средняя награда: 0.0
# Шаг времени: 2000, Средняя награда: 0.001
# Шаг времени: 3000, Средняя награда: 0.002
# Шаг времени: 4000, Средняя награда: 0.011
# Шаг времени: 5000, Средняя награда: 0.017
# Шаг времени: 6000, Средняя награда: 0.003
# Шаг времени: 7000, Средняя награда: 0.014
# Шаг времени: 8000, Средняя награда: 0.045
# Шаг времени: 9000, Средняя награда: 0.114
# Шаг времени: 10000, Средняя награда: 0.149
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 2.63     |
# | time/                 |          |
# |    fps                | 853      |
# |    iterations         | 100      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.34    |
# |    explained_variance | -0.0289  |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 99       |
# |    policy_loss        | 1.14     |
# |    value_loss         | 3.35     |
# ------------------------------------
# Шаг времени: 11000, Средняя награда: 0.24
# Шаг времени: 12000, Средняя награда: 0.359
# Шаг времени: 13000, Средняя награда: 0.376
# Шаг времени: 14000, Средняя награда: 0.351
# Шаг времени: 15000, Средняя награда: 0.46
# Шаг времени: 16000, Средняя награда: 0.45
# Шаг времени: 17000, Средняя награда: 0.494
# Шаг времени: 18000, Средняя награда: 0.463
# Шаг времени: 19000, Средняя награда: 0.52
# Шаг времени: 20000, Средняя награда: 0.454
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 9.74     |
# | time/                 |          |
# |    fps                | 854      |
# |    iterations         | 200      |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.909   |
# |    explained_variance | 0.0722   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 199      |
# |    policy_loss        | 0.666    |
# |    value_loss         | 9.07     |
# ------------------------------------
# Запуск lifetime 1997...
# Goal position: [3, 5]
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Шаг времени: 1000, Средняя награда: 0.032
# Шаг времени: 2000, Средняя награда: 0.039
# Шаг времени: 3000, Средняя награда: 0.047
# Шаг времени: 4000, Средняя награда: 0.032
# Шаг времени: 5000, Средняя награда: 0.057
# Шаг времени: 6000, Средняя награда: 0.036
# Шаг времени: 7000, Средняя награда: 0.07
# Шаг времени: 8000, Средняя награда: 0.062
# Шаг времени: 9000, Средняя награда: 0.06
# Шаг времени: 10000, Средняя награда: 0.063
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 1.23     |
# | time/                 |          |
# |    fps                | 815      |
# |    iterations         | 100      |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.57    |
# |    explained_variance | 0.0646   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 99       |
# |    policy_loss        | -0.159   |
# |    value_loss         | 0.344    |
# ------------------------------------
# Шаг времени: 11000, Средняя награда: 0.06
# Шаг времени: 12000, Средняя награда: 0.061
# Шаг времени: 13000, Средняя награда: 0.079
# Шаг времени: 14000, Средняя награда: 0.078
# Шаг времени: 15000, Средняя награда: 0.087
# Шаг времени: 16000, Средняя награда: 0.084
# Шаг времени: 17000, Средняя награда: 0.084
# Шаг времени: 18000, Средняя награда: 0.091
# Шаг времени: 19000, Средняя награда: 0.084
# Шаг времени: 20000, Средняя награда: 0.089
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 1.73     |
# | time/                 |          |
# |    fps                | 802      |
# |    iterations         | 200      |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -1.52    |
# |    explained_variance | 0.205    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 199      |
# |    policy_loss        | -0.0365  |
# |    value_loss         | 0.53     |
# ------------------------------------
# Запуск lifetime 1998...
# Goal position: [6, 3]
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Шаг времени: 1000, Средняя награда: 0.013
# Шаг времени: 2000, Средняя награда: 0.04
# Шаг времени: 3000, Средняя награда: 0.036
# Шаг времени: 4000, Средняя награда: 0.04
# Шаг времени: 5000, Средняя награда: 0.041
# Шаг времени: 6000, Средняя награда: 0.043
# Шаг времени: 7000, Средняя награда: 0.059
# Шаг времени: 8000, Средняя награда: 0.039
# Шаг времени: 9000, Средняя награда: 0.046
# Шаг времени: 10000, Средняя награда: 0.048
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 0.94     |
# | time/                 |          |
# |    fps                | 817      |
# |    iterations         | 100      |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.55    |
# |    explained_variance | -0.058   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 99       |
# |    policy_loss        | 0.482    |
# |    value_loss         | 0.921    |
# ------------------------------------
# Шаг времени: 11000, Средняя награда: 0.051
# Шаг времени: 12000, Средняя награда: 0.047
# Шаг времени: 13000, Средняя награда: 0.058
# Шаг времени: 14000, Средняя награда: 0.068
# Шаг времени: 15000, Средняя награда: 0.052
# Шаг времени: 16000, Средняя награда: 0.058
# Шаг времени: 17000, Средняя награда: 0.071
# Шаг времени: 18000, Средняя награда: 0.061
# Шаг времени: 19000, Средняя награда: 0.068
# Шаг времени: 20000, Средняя награда: 0.067
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 1.35     |
# | time/                 |          |
# |    fps                | 812      |
# |    iterations         | 200      |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -1.44    |
# |    explained_variance | 0.0996   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 199      |
# |    policy_loss        | -0.0616  |
# |    value_loss         | 0.729    |
# ------------------------------------
# Запуск lifetime 1999...
# Goal position: [4, 8]
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Шаг времени: 1000, Средняя награда: 0.001
# Шаг времени: 2000, Средняя награда: 0.006
# Шаг времени: 3000, Средняя награда: 0.027
# Шаг времени: 4000, Средняя награда: 0.025
# Шаг времени: 5000, Средняя награда: 0.038
# Шаг времени: 6000, Средняя награда: 0.053
# Шаг времени: 7000, Средняя награда: 0.076
# Шаг времени: 8000, Средняя награда: 0.146
# Шаг времени: 9000, Средняя награда: 0.135
# Шаг времени: 10000, Средняя награда: 0.237
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 3.72     |
# | time/                 |          |
# |    fps                | 821      |
# |    iterations         | 100      |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.15    |
# |    explained_variance | -0.0202  |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 99       |
# |    policy_loss        | 0.158    |
# |    value_loss         | 5.37     |
# ------------------------------------
# Шаг времени: 11000, Средняя награда: 0.268
# Шаг времени: 12000, Средняя награда: 0.22
# Шаг времени: 13000, Средняя награда: 0.257
# Шаг времени: 14000, Средняя награда: 0.357
# Шаг времени: 15000, Средняя награда: 0.444
# Шаг времени: 16000, Средняя награда: 0.417
# Шаг времени: 17000, Средняя награда: 0.482
# Шаг времени: 18000, Средняя награда: 0.505
# Шаг времени: 19000, Средняя награда: 0.511
# Шаг времени: 20000, Средняя награда: 0.569
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 10.8     |
# | time/                 |          |
# |    fps                | 819      |
# |    iterations         | 200      |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.481   |
# |    explained_variance | 0.0535   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 199      |
# |    policy_loss        | -1.35    |
# |    value_loss         | 14.6     |
# ------------------------------------

# %% [markdown]
# ## Сохраняем

# %%
# !zip -r /content/all_files.zip /content
# Out:
# updating: content/ (stored 0%)
# updating: content/.config/ (stored 0%)
# updating: content/.config/gce (stored 0%)
# updating: content/.config/active_config (stored 0%)
# updating: content/.config/default_configs.db (deflated 98%)
# updating: content/.config/.last_update_check.json (deflated 22%)
# updating: content/.config/logs/ (stored 0%)
# updating: content/.config/logs/2024.07.31/ (stored 0%)
# updating: content/.config/logs/2024.07.31/19.24.37.450020.log (deflated 85%)
# updating: content/.config/logs/2024.07.31/19.24.38.677192.log (deflated 58%)
# updating: content/.config/logs/2024.07.31/19.24.27.578537.log (deflated 58%)
# updating: content/.config/logs/2024.07.31/19.24.48.277971.log (deflated 57%)
# updating: content/.config/logs/2024.07.31/19.24.48.872630.log (deflated 56%)
# updating: content/.config/logs/2024.07.31/19.24.05.521263.log (deflated 93%)
# updating: content/.config/.last_survey_prompt.yaml (stored 0%)
# updating: content/.config/.last_opt_in_prompt.yaml (stored 0%)
# updating: content/.config/config_sentinel (stored 0%)
# updating: content/.config/configurations/ (stored 0%)
# updating: content/.config/configurations/config_default (deflated 15%)
# updating: content/darkroom_normal_1543.pkl (deflated 90%)
# updating: content/darkroom_normal_1552.pkl (deflated 92%)
# updating: content/darkroom_normal_1557.pkl (deflated 92%)
# updating: content/darkroom_normal_1503.pkl (deflated 93%)
# updating: content/darkroom_normal_1548.pkl (deflated 90%)
# updating: content/darkroom_normal_1594.pkl (deflated 92%)
# updating: content/darkroom_normal_1587.pkl (deflated 92%)
# updating: content/darkroom_normal_1591.pkl (deflated 90%)
# updating: content/darkroom_normal_1564.pkl (deflated 91%)
# updating: content/darkroom_normal_1542.pkl (deflated 90%)
# updating: content/darkroom_normal_1497.pkl (deflated 92%)
# updating: content/darkroom_normal_1502.pkl (deflated 90%)
# updating: content/darkroom_normal_1527.pkl (deflated 93%)
# updating: content/darkroom_normal_1460.pkl (deflated 90%)
# updating: content/darkroom_normal_1455.pkl (deflated 92%)
# updating: content/darkroom_normal_1515.pkl (deflated 90%)
# updating: content/darkroom_normal_1510.pkl (deflated 90%)
# updating: content/darkroom_normal_1496.pkl (deflated 92%)
# updating: content/darkroom_normal_1537.pkl (deflated 92%)
# updating: content/darkroom_normal_1495.pkl (deflated 90%)
# updating: content/darkroom_normal_1571.pkl (deflated 90%)
# updating: content/darkroom_normal_1532.pkl (deflated 91%)
# updating: content/darkroom_normal_1493.pkl (deflated 92%)
# updating: content/darkroom_normal_1582.pkl (deflated 93%)
# updating: content/darkroom_normal_1487.pkl (deflated 90%)
# updating: content/darkroom_normal_1577.pkl (deflated 91%)
# updating: content/darkroom_normal_1475.pkl (deflated 92%)
# updating: content/darkroom_normal_1598.pkl (deflated 90%)
# updating: content/darkroom_normal_1565.pkl (deflated 91%)
# updating: content/darkroom_normal_1462.pkl (deflated 92%)
# updating: content/darkroom_normal_1519.pkl (deflated 91%)
# updating: content/darkroom_normal_1511.pkl (deflated 90%)
# updating: content/darkroom_normal_1516.pkl (deflated 93%)
# updating: content/darkroom_normal_1585.pkl (deflated 92%)
# updating: content/darkroom_normal_1466.pkl (deflated 92%)
# updating: content/darkroom_normal_1593.pkl (deflated 90%)
# updating: content/darkroom_normal_1467.pkl (deflated 90%)
# updating: content/darkroom_normal_1580.pkl (deflated 91%)
# updating: content/envs/ (stored 0%)
# updating: content/envs/__init__.py (deflated 67%)
# updating: content/envs/darkroom.py (deflated 67%)
# updating: content/envs/__pycache__/ (stored 0%)
# updating: content/envs/__pycache__/__init__.cpython-310.pyc (deflated 42%)
# updating: content/envs/__pycache__/darkroom.cpython-310.pyc (deflated 49%)
# updating: content/darkroom_normal_1553.pkl (deflated 93%)
# updating: content/darkroom_normal_1512.pkl (deflated 95%)
# updating: content/darkroom_normal_1452.pkl (deflated 92%)
# updating: content/darkroom_normal_1464.pkl (deflated 90%)
# updating: content/darkroom_normal_1470.pkl (deflated 91%)
# updating: content/darkroom_normal_1592.pkl (deflated 90%)
# updating: content/darkroom_normal_1468.pkl (deflated 94%)
# updating: content/darkroom_normal_1588.pkl (deflated 90%)
# updating: content/darkroom_normal_1480.pkl (deflated 92%)
# updating: content/darkroom_normal_1476.pkl (deflated 91%)
# updating: content/darkroom_normal_1526.pkl (deflated 93%)
# updating: content/wandb/ (stored 0%)
# updating: content/wandb/latest-run/ (stored 0%)
# updating: content/wandb/latest-run/tmp/ (stored 0%)
# updating: content/wandb/latest-run/tmp/code/ (stored 0%)
# updating: content/wandb/latest-run/logs/ (stored 0%)
# updating: content/wandb/latest-run/logs/debug-internal.log (deflated 96%)
# updating: content/wandb/latest-run/logs/debug.log (deflated 72%)
# updating: content/wandb/latest-run/files/ (stored 0%)
# updating: content/wandb/latest-run/files/requirements.txt (deflated 56%)
# updating: content/wandb/latest-run/files/config.yaml (deflated 65%)
# updating: content/wandb/latest-run/files/wandb-summary.json (deflated 15%)
# updating: content/wandb/latest-run/files/wandb-metadata.json (deflated 55%)
# updating: content/wandb/latest-run/files/output.log (deflated 94%)
# updating: content/wandb/run-20240802_070218-5uduhrog/ (stored 0%)
# updating: content/wandb/run-20240802_070218-5uduhrog/run-5uduhrog.wandb (deflated 79%)
# updating: content/wandb/run-20240802_070218-5uduhrog/tmp/ (stored 0%)
# updating: content/wandb/run-20240802_070218-5uduhrog/tmp/code/ (stored 0%)
# updating: content/wandb/run-20240802_070218-5uduhrog/logs/ (stored 0%)
# updating: content/wandb/run-20240802_070218-5uduhrog/logs/debug-internal.log (deflated 96%)
# updating: content/wandb/run-20240802_070218-5uduhrog/logs/debug.log (deflated 80%)
# updating: content/wandb/run-20240802_070218-5uduhrog/files/ (stored 0%)
# updating: content/wandb/run-20240802_070218-5uduhrog/files/requirements.txt (deflated 56%)
# updating: content/wandb/run-20240802_070218-5uduhrog/files/config.yaml (deflated 65%)
# updating: content/wandb/run-20240802_070218-5uduhrog/files/wandb-summary.json (deflated 23%)
# updating: content/wandb/run-20240802_070218-5uduhrog/files/wandb-metadata.json (deflated 55%)
# updating: content/wandb/run-20240802_070218-5uduhrog/files/output.log (deflated 94%)
# updating: content/wandb/debug-internal.log (deflated 96%)
# updating: content/wandb/debug.log (deflated 72%)
# updating: content/darkroom_normal_1469.pkl (deflated 92%)
# updating: content/darkroom_normal_1533.pkl (deflated 92%)
# updating: content/darkroom_normal_1554.pkl (deflated 90%)
# updating: content/darkroom_normal_1567.pkl (deflated 90%)
# updating: content/darkroom_normal_1520.pkl (deflated 90%)
# updating: content/darkroom_normal_1581.pkl (deflated 92%)
# updating: content/darkroom_normal_1590.pkl (deflated 90%)
# updating: content/darkroom_normal_1451.pkl (deflated 90%)
# updating: content/darkroom_normal_1482.pkl (deflated 92%)
# updating: content/darkroom_normal_1579.pkl (deflated 90%)
# updating: content/darkroom_normal_1504.pkl (deflated 90%)
# updating: content/darkroom_normal_1568.pkl (deflated 92%)
# updating: content/darkroom_normal_1540.pkl (deflated 90%)
# updating: content/darkroom_normal_1517.pkl (deflated 93%)
# updating: content/darkroom_normal_1450.pkl (deflated 92%)
# updating: content/darkroom_normal_1550.pkl (deflated 91%)
# updating: content/darkroom_normal_1555.pkl (deflated 92%)
# updating: content/darkroom_normal_1544.pkl (deflated 91%)
# updating: content/darkroom_normal_1584.pkl (deflated 90%)
# updating: content/darkroom_normal_1572.pkl (deflated 90%)
# updating: content/darkroom_normal_1528.pkl (deflated 90%)
# updating: content/darkroom_normal_1457.pkl (deflated 90%)
# updating: content/darkroom_normal_1576.pkl (deflated 91%)
# updating: content/darkroom_normal_1454.pkl (deflated 93%)
# updating: content/darkroom_normal_1461.pkl (deflated 92%)
# updating: content/darkroom_normal_1596.pkl (deflated 90%)
# updating: content/darkroom_normal_1539.pkl (deflated 90%)
# updating: content/darkroom_normal_1453.pkl (deflated 90%)
# updating: content/darkroom_normal_1473.pkl (deflated 92%)
# updating: content/darkroom_normal_1489.pkl (deflated 90%)
# updating: content/darkroom_normal_1485.pkl (deflated 93%)
# updating: content/darkroom_normal_1541.pkl (deflated 90%)
# updating: content/darkroom_normal_1459.pkl (deflated 91%)
# updating: content/darkroom_normal_1583.pkl (deflated 92%)
# updating: content/darkroom_normal_1574.pkl (deflated 90%)
# updating: content/darkroom_normal_1505.pkl (deflated 90%)
# updating: content/darkroom_normal_1525.pkl (deflated 90%)
# updating: content/darkroom_normal_1566.pkl (deflated 90%)
# updating: content/darkroom_normal_1481.pkl (deflated 90%)
# updating: content/darkroom_normal_1521.pkl (deflated 93%)
# updating: content/darkroom_normal_1563.pkl (deflated 90%)
# updating: content/darkroom_normal_1513.pkl (deflated 94%)
# updating: content/darkroom_normal_1549.pkl (deflated 91%)
# updating: content/darkroom_normal_1478.pkl (deflated 90%)
# updating: content/darkroom_normal_1535.pkl (deflated 91%)
# updating: content/configs/ (stored 0%)
# updating: content/configs/DarkRoom-a2c.json (deflated 47%)
# updating: content/darkroom_normal_1529.pkl (deflated 92%)
# updating: content/darkroom_normal_1490.pkl (deflated 92%)
# updating: content/darkroom_normal_1501.pkl (deflated 91%)
# updating: content/darkroom_normal_1506.pkl (deflated 91%)
# updating: content/darkroom_normal_1570.pkl (deflated 90%)
# updating: content/darkroom_normal_1484.pkl (deflated 90%)
# updating: content/darkroom_normal_1534.pkl (deflated 93%)
# updating: content/darkroom_normal_1524.pkl (deflated 94%)
# updating: content/darkroom_normal_1578.pkl (deflated 91%)
# updating: content/darkroom_normal_1509.pkl (deflated 91%)
# updating: content/darkroom_normal_1474.pkl (deflated 92%)
# updating: content/darkroom_normal_1494.pkl (deflated 91%)
# updating: content/darkroom_normal_1551.pkl (deflated 90%)
# updating: content/darkroom_normal_1518.pkl (deflated 92%)
# updating: content/darkroom_normal_1597.pkl (deflated 90%)
# updating: content/darkroom_normal_1465.pkl (deflated 92%)
# updating: content/darkroom_normal_1599.pkl (deflated 93%)
# updating: content/.ipynb_checkpoints/ (stored 0%)
# updating: content/darkroom_normal_1471.pkl (deflated 91%)
# updating: content/darkroom_normal_1456.pkl (deflated 92%)
# updating: content/darkroom_normal_1488.pkl (deflated 92%)
# updating: content/darkroom_normal_1556.pkl (deflated 90%)
# updating: content/darkroom_normal_1547.pkl (deflated 93%)
# updating: content/darkroom_normal_1569.pkl (deflated 92%)
# updating: content/darkroom_normal_1561.pkl (deflated 93%)
# updating: content/darkroom_normal_1575.pkl (deflated 90%)
# updating: content/darkroom_normal_1477.pkl (deflated 91%)
# updating: content/darkroom_normal_1562.pkl (deflated 90%)
# updating: content/darkroom_normal_1491.pkl (deflated 93%)
# updating: content/darkroom_normal_1458.pkl (deflated 93%)
# updating: content/darkroom_normal_1492.pkl (deflated 90%)
# updating: content/darkroom_normal_1536.pkl (deflated 90%)
# updating: content/darkroom_normal_1514.pkl (deflated 90%)
# updating: content/darkroom_normal_1463.pkl (deflated 93%)
# updating: content/darkroom_normal_1507.pkl (deflated 93%)
# updating: content/darkroom_normal_1595.pkl (deflated 93%)
# updating: content/darkroom_normal_1483.pkl (deflated 90%)
# updating: content/darkroom_normal_1472.pkl (deflated 92%)
# updating: content/darkroom_normal_1530.pkl (deflated 90%)
# updating: content/darkroom_normal_1546.pkl (deflated 90%)
# updating: content/darkroom_normal_1531.pkl (deflated 92%)
# updating: content/darkroom_normal_1523.pkl (deflated 90%)
# updating: content/darkroom_normal_1522.pkl (deflated 92%)
# updating: content/darkroom_normal_1559.pkl (deflated 91%)
# updating: content/darkroom_normal_1499.pkl (deflated 91%)
# updating: content/darkroom_normal_1500.pkl (deflated 90%)
# updating: content/darkroom_normal_1486.pkl (deflated 90%)
# updating: content/darkroom_normal_1558.pkl (deflated 90%)
# updating: content/darkroom_normal_1498.pkl (deflated 90%)
# updating: content/darkroom_normal_1560.pkl (deflated 90%)
# updating: content/darkroom_normal_1538.pkl (deflated 90%)
# updating: content/darkroom_normal_1586.pkl (deflated 90%)
# updating: content/darkroom_normal_1573.pkl (deflated 90%)
# updating: content/darkroom_normal_1479.pkl (deflated 90%)
# updating: content/darkroom_normal_1589.pkl (deflated 90%)
# updating: content/darkroom_normal_1508.pkl (deflated 91%)
# updating: content/darkroom_normal_1545.pkl (deflated 92%)
# updating: content/sample_data/ (stored 0%)
# updating: content/sample_data/README.md (deflated 42%)
# updating: content/sample_data/anscombe.json (deflated 83%)
# updating: content/sample_data/california_housing_train.csv (deflated 79%)
# updating: content/sample_data/mnist_test.csv (deflated 88%)
# updating: content/sample_data/mnist_train_small.csv (deflated 88%)
# updating: content/sample_data/california_housing_test.csv (deflated 76%)
# updating: content/darkroom_normal_1748.pkl (deflated 91%)
# updating: content/darkroom_normal_1729.pkl (deflated 93%)
# updating: content/darkroom_normal_1645.pkl (deflated 90%)
# updating: content/darkroom_normal_1747.pkl (deflated 92%)
# updating: content/darkroom_normal_1712.pkl (deflated 91%)
# updating: content/darkroom_normal_1793.pkl (deflated 90%)
# updating: content/darkroom_normal_1740.pkl (deflated 90%)
# updating: content/darkroom_normal_1648.pkl (deflated 90%)
# updating: content/darkroom_normal_1634.pkl (deflated 91%)
# updating: content/darkroom_normal_1649.pkl (deflated 90%)
# updating: content/darkroom_normal_1794.pkl (deflated 93%)
# updating: content/darkroom_normal_1731.pkl (deflated 90%)
# updating: content/darkroom_normal_1781.pkl (deflated 90%)
# updating: content/darkroom_normal_1678.pkl (deflated 92%)
# updating: content/darkroom_normal_1665.pkl (deflated 91%)
# updating: content/darkroom_normal_1611.pkl (deflated 90%)
# updating: content/darkroom_normal_1625.pkl (deflated 90%)
# updating: content/darkroom_normal_1795.pkl (deflated 91%)
# updating: content/darkroom_normal_1642.pkl (deflated 91%)
# updating: content/darkroom_normal_1725.pkl (deflated 90%)
# updating: content/darkroom_normal_1604.pkl (deflated 90%)
# updating: content/darkroom_normal_1606.pkl (deflated 90%)
# updating: content/darkroom_normal_1673.pkl (deflated 90%)
# updating: content/darkroom_normal_1711.pkl (deflated 92%)
# updating: content/darkroom_normal_1769.pkl (deflated 92%)
# updating: content/darkroom_normal_1615.pkl (deflated 91%)
# updating: content/darkroom_normal_1657.pkl (deflated 90%)
# updating: content/darkroom_normal_1658.pkl (deflated 91%)
# updating: content/darkroom_normal_1661.pkl (deflated 90%)
# updating: content/darkroom_normal_1776.pkl (deflated 92%)
# updating: content/darkroom_normal_1613.pkl (deflated 91%)
# updating: content/darkroom_normal_1626.pkl (deflated 90%)
# updating: content/darkroom_normal_1715.pkl (deflated 90%)
# updating: content/darkroom_normal_1688.pkl (deflated 91%)
# updating: content/darkroom_normal_1710.pkl (deflated 92%)
# updating: content/darkroom_normal_1706.pkl (deflated 91%)
# updating: content/darkroom_normal_1603.pkl (deflated 90%)
# updating: content/darkroom_normal_1797.pkl (deflated 90%)
# updating: content/darkroom_normal_1652.pkl (deflated 91%)
# updating: content/darkroom_normal_1605.pkl (deflated 90%)
# updating: content/darkroom_normal_1650.pkl (deflated 92%)
# updating: content/darkroom_normal_1771.pkl (deflated 90%)
# updating: content/darkroom_normal_1775.pkl (deflated 90%)
# updating: content/darkroom_normal_1756.pkl (deflated 90%)
# updating: content/darkroom_normal_1672.pkl (deflated 92%)
# updating: content/darkroom_normal_1790.pkl (deflated 92%)
# updating: content/darkroom_normal_1683.pkl (deflated 91%)
# updating: content/darkroom_normal_1635.pkl (deflated 90%)
# updating: content/darkroom_normal_1763.pkl (deflated 94%)
# updating: content/darkroom_normal_1700.pkl (deflated 91%)
# updating: content/darkroom_normal_1667.pkl (deflated 92%)
# updating: content/darkroom_normal_1786.pkl (deflated 92%)
# updating: content/darkroom_normal_1632.pkl (deflated 91%)
# updating: content/darkroom_normal_1637.pkl (deflated 90%)
# updating: content/darkroom_normal_1619.pkl (deflated 94%)
# updating: content/darkroom_normal_1787.pkl (deflated 92%)
# updating: content/darkroom_normal_1633.pkl (deflated 91%)
# updating: content/darkroom_normal_1777.pkl (deflated 90%)
# updating: content/darkroom_normal_1708.pkl (deflated 92%)
# updating: content/darkroom_normal_1691.pkl (deflated 90%)
# updating: content/darkroom_normal_1742.pkl (deflated 90%)
# updating: content/darkroom_normal_1718.pkl (deflated 93%)
# updating: content/darkroom_normal_1785.pkl (deflated 91%)
# updating: content/darkroom_normal_1676.pkl (deflated 90%)
# updating: content/darkroom_normal_1757.pkl (deflated 91%)
# updating: content/darkroom_normal_1621.pkl (deflated 92%)
# updating: content/darkroom_normal_1737.pkl (deflated 91%)
# updating: content/darkroom_normal_1640.pkl (deflated 92%)
# updating: content/darkroom_normal_1630.pkl (deflated 91%)
# updating: content/wandb/run-20240802_080906-rsmn3fbc/ (stored 0%)
# updating: content/wandb/run-20240802_080906-rsmn3fbc/run-rsmn3fbc.wandb (deflated 79%)
# updating: content/wandb/run-20240802_080906-rsmn3fbc/tmp/ (stored 0%)
# updating: content/wandb/run-20240802_080906-rsmn3fbc/tmp/code/ (stored 0%)
# updating: content/wandb/run-20240802_080906-rsmn3fbc/logs/ (stored 0%)
# updating: content/wandb/run-20240802_080906-rsmn3fbc/logs/debug-internal.log (deflated 96%)
# updating: content/wandb/run-20240802_080906-rsmn3fbc/logs/debug.log (deflated 83%)
# updating: content/wandb/run-20240802_080906-rsmn3fbc/files/ (stored 0%)
# updating: content/wandb/run-20240802_080906-rsmn3fbc/files/requirements.txt (deflated 56%)
# updating: content/wandb/run-20240802_080906-rsmn3fbc/files/config.yaml (deflated 65%)
# updating: content/wandb/run-20240802_080906-rsmn3fbc/files/wandb-summary.json (deflated 24%)
# updating: content/wandb/run-20240802_080906-rsmn3fbc/files/wandb-metadata.json (deflated 55%)
# updating: content/wandb/run-20240802_080906-rsmn3fbc/files/output.log (deflated 94%)
# updating: content/darkroom_normal_1608.pkl (deflated 90%)
# updating: content/darkroom_normal_1612.pkl (deflated 90%)
# updating: content/darkroom_normal_1788.pkl (deflated 93%)
# updating: content/darkroom_normal_1675.pkl (deflated 93%)
# updating: content/darkroom_normal_1722.pkl (deflated 91%)
# updating: content/darkroom_normal_1719.pkl (deflated 90%)
# updating: content/darkroom_normal_1696.pkl (deflated 91%)
# updating: content/darkroom_normal_1721.pkl (deflated 92%)
# updating: content/darkroom_normal_1689.pkl (deflated 90%)
# updating: content/darkroom_normal_1770.pkl (deflated 91%)
# updating: content/darkroom_normal_1628.pkl (deflated 91%)
# updating: content/darkroom_normal_1751.pkl (deflated 93%)
# updating: content/darkroom_normal_1772.pkl (deflated 90%)
# updating: content/darkroom_normal_1624.pkl (deflated 90%)
# updating: content/darkroom_normal_1761.pkl (deflated 90%)
# updating: content/darkroom_normal_1728.pkl (deflated 90%)
# updating: content/darkroom_normal_1660.pkl (deflated 91%)
# updating: content/darkroom_normal_1746.pkl (deflated 93%)
# updating: content/darkroom_normal_1669.pkl (deflated 90%)
# updating: content/darkroom_normal_1727.pkl (deflated 92%)
# updating: content/darkroom_normal_1654.pkl (deflated 90%)
# updating: content/darkroom_normal_1709.pkl (deflated 93%)
# updating: content/darkroom_normal_1754.pkl (deflated 93%)
# updating: content/darkroom_normal_1749.pkl (deflated 91%)
# updating: content/darkroom_normal_1602.pkl (deflated 90%)
# updating: content/darkroom_normal_1618.pkl (deflated 90%)
# updating: content/darkroom_normal_1651.pkl (deflated 90%)
# updating: content/darkroom_normal_1607.pkl (deflated 91%)
# updating: content/darkroom_normal_1707.pkl (deflated 94%)
# updating: content/darkroom_normal_1690.pkl (deflated 90%)
# updating: content/darkroom_normal_1617.pkl (deflated 91%)
# updating: content/darkroom_normal_1698.pkl (deflated 92%)
# updating: content/darkroom_normal_1639.pkl (deflated 90%)
# updating: content/darkroom_normal_1726.pkl (deflated 90%)
# updating: content/darkroom_normal_1734.pkl (deflated 90%)
# updating: content/darkroom_normal_1699.pkl (deflated 90%)
# updating: content/darkroom_normal_1686.pkl (deflated 93%)
# updating: content/darkroom_normal_1766.pkl (deflated 92%)
# updating: content/darkroom_normal_1701.pkl (deflated 90%)
# updating: content/darkroom_normal_1655.pkl (deflated 93%)
# updating: content/darkroom_normal_1765.pkl (deflated 90%)
# updating: content/darkroom_normal_1685.pkl (deflated 92%)
# updating: content/darkroom_normal_1627.pkl (deflated 91%)
# updating: content/darkroom_normal_1638.pkl (deflated 94%)
# updating: content/darkroom_normal_1664.pkl (deflated 92%)
# updating: content/darkroom_normal_1735.pkl (deflated 93%)
# updating: content/darkroom_normal_1716.pkl (deflated 91%)
# updating: content/darkroom_normal_1609.pkl (deflated 90%)
# updating: content/darkroom_normal_1796.pkl (deflated 92%)
# updating: content/darkroom_normal_1713.pkl (deflated 90%)
# updating: content/darkroom_normal_1646.pkl (deflated 90%)
# updating: content/darkroom_normal_1656.pkl (deflated 90%)
# updating: content/darkroom_normal_1745.pkl (deflated 90%)
# updating: content/darkroom_normal_1610.pkl (deflated 90%)
# updating: content/darkroom_normal_1724.pkl (deflated 91%)
# updating: content/darkroom_normal_1692.pkl (deflated 92%)
# updating: content/darkroom_normal_1732.pkl (deflated 90%)
# updating: content/darkroom_normal_1636.pkl (deflated 92%)
# updating: content/darkroom_normal_1738.pkl (deflated 92%)
# updating: content/darkroom_normal_1623.pkl (deflated 90%)
# updating: content/darkroom_normal_1647.pkl (deflated 93%)
# updating: content/darkroom_normal_1733.pkl (deflated 91%)
# updating: content/darkroom_normal_1614.pkl (deflated 90%)
# updating: content/darkroom_normal_1762.pkl (deflated 90%)
# updating: content/darkroom_normal_1663.pkl (deflated 90%)
# updating: content/darkroom_normal_1680.pkl (deflated 91%)
# updating: content/darkroom_normal_1694.pkl (deflated 95%)
# updating: content/darkroom_normal_1714.pkl (deflated 91%)
# updating: content/darkroom_normal_1753.pkl (deflated 93%)
# updating: content/darkroom_normal_1717.pkl (deflated 90%)
# updating: content/darkroom_normal_1739.pkl (deflated 92%)
# updating: content/darkroom_normal_1668.pkl (deflated 90%)
# updating: content/darkroom_normal_1622.pkl (deflated 90%)
# updating: content/darkroom_normal_1674.pkl (deflated 90%)
# updating: content/darkroom_normal_1600.pkl (deflated 90%)
# updating: content/darkroom_normal_1666.pkl (deflated 90%)
# updating: content/darkroom_normal_1704.pkl (deflated 95%)
# updating: content/darkroom_normal_1697.pkl (deflated 90%)
# updating: content/darkroom_normal_1670.pkl (deflated 90%)
# updating: content/darkroom_normal_1703.pkl (deflated 93%)
# updating: content/darkroom_normal_1684.pkl (deflated 93%)
# updating: content/darkroom_normal_1784.pkl (deflated 90%)
# updating: content/darkroom_normal_1779.pkl (deflated 90%)
# updating: content/darkroom_normal_1616.pkl (deflated 92%)
# updating: content/darkroom_normal_1629.pkl (deflated 92%)
# updating: content/darkroom_normal_1643.pkl (deflated 90%)
# updating: content/darkroom_normal_1702.pkl (deflated 90%)
# updating: content/darkroom_normal_1780.pkl (deflated 94%)
# updating: content/darkroom_normal_1671.pkl (deflated 92%)
# updating: content/darkroom_normal_1789.pkl (deflated 90%)
# updating: content/darkroom_normal_1752.pkl (deflated 90%)
# updating: content/darkroom_normal_1695.pkl (deflated 90%)
# updating: content/darkroom_normal_1687.pkl (deflated 90%)
# updating: content/darkroom_normal_1758.pkl (deflated 90%)
# updating: content/darkroom_normal_1723.pkl (deflated 90%)
# updating: content/darkroom_normal_1759.pkl (deflated 90%)
# updating: content/darkroom_normal_1778.pkl (deflated 91%)
# updating: content/darkroom_normal_1744.pkl (deflated 90%)
# updating: content/darkroom_normal_1641.pkl (deflated 94%)
# updating: content/darkroom_normal_1693.pkl (deflated 93%)
# updating: content/darkroom_normal_1741.pkl (deflated 92%)
# updating: content/darkroom_normal_1750.pkl (deflated 90%)
# updating: content/darkroom_normal_1662.pkl (deflated 90%)
# updating: content/darkroom_normal_1760.pkl (deflated 90%)
# updating: content/darkroom_normal_1764.pkl (deflated 92%)
# updating: content/darkroom_normal_1782.pkl (deflated 90%)
# updating: content/darkroom_normal_1720.pkl (deflated 91%)
# updating: content/darkroom_normal_1798.pkl (deflated 93%)
# updating: content/darkroom_normal_1653.pkl (deflated 90%)
# updating: content/darkroom_normal_1768.pkl (deflated 92%)
# updating: content/darkroom_normal_1736.pkl (deflated 90%)
# updating: content/darkroom_normal_1783.pkl (deflated 93%)
# updating: content/darkroom_normal_1682.pkl (deflated 90%)
# updating: content/darkroom_normal_1644.pkl (deflated 91%)
# updating: content/darkroom_normal_1620.pkl (deflated 90%)
# updating: content/darkroom_normal_1631.pkl (deflated 91%)
# updating: content/darkroom_normal_1755.pkl (deflated 91%)
# updating: content/darkroom_normal_1792.pkl (deflated 92%)
# updating: content/darkroom_normal_1659.pkl (deflated 90%)
# updating: content/darkroom_normal_1743.pkl (deflated 93%)
# updating: content/darkroom_normal_1601.pkl (deflated 91%)
# updating: content/darkroom_normal_1677.pkl (deflated 92%)
# updating: content/darkroom_normal_1705.pkl (deflated 91%)
# updating: content/darkroom_normal_1679.pkl (deflated 93%)
# updating: content/darkroom_normal_1791.pkl (deflated 91%)
# updating: content/darkroom_normal_1730.pkl (deflated 90%)
# updating: content/darkroom_normal_1774.pkl (deflated 92%)
# updating: content/darkroom_normal_1773.pkl (deflated 91%)
# updating: content/darkroom_normal_1681.pkl (deflated 90%)
# updating: content/darkroom_normal_1799.pkl (deflated 91%)
# updating: content/darkroom_normal_1767.pkl (deflated 90%)
#   adding: content/darkroom_normal_1939.pkl (deflated 93%)
#   adding: content/darkroom_normal_1867.pkl (deflated 90%)
#   adding: content/darkroom_normal_1940.pkl (deflated 90%)
#   adding: content/darkroom_normal_1833.pkl (deflated 92%)
#   adding: content/darkroom_normal_1884.pkl (deflated 90%)
#   adding: content/darkroom_normal_1926.pkl (deflated 90%)
#   adding: content/darkroom_normal_1913.pkl (deflated 90%)
#   adding: content/darkroom_normal_1931.pkl (deflated 93%)
#   adding: content/darkroom_normal_1827.pkl (deflated 90%)
#   adding: content/darkroom_normal_1840.pkl (deflated 94%)
#   adding: content/darkroom_normal_1915.pkl (deflated 90%)
#   adding: content/darkroom_normal_1868.pkl (deflated 95%)
#   adding: content/darkroom_normal_1914.pkl (deflated 92%)
#   adding: content/darkroom_normal_1802.pkl (deflated 93%)
#   adding: content/darkroom_normal_1991.pkl (deflated 94%)
#   adding: content/darkroom_normal_1837.pkl (deflated 93%)
#   adding: content/darkroom_normal_1910.pkl (deflated 92%)
#   adding: content/darkroom_normal_1886.pkl (deflated 90%)
#   adding: content/darkroom_normal_1818.pkl (deflated 90%)
#   adding: content/darkroom_normal_1820.pkl (deflated 90%)
#   adding: content/darkroom_normal_1922.pkl (deflated 90%)
#   adding: content/darkroom_normal_1862.pkl (deflated 90%)
#   adding: content/darkroom_normal_1846.pkl (deflated 90%)
#   adding: content/darkroom_normal_1836.pkl (deflated 91%)
#   adding: content/darkroom_normal_1902.pkl (deflated 91%)
#   adding: content/darkroom_normal_1828.pkl (deflated 92%)
#   adding: content/darkroom_normal_1950.pkl (deflated 92%)
#   adding: content/darkroom_normal_1858.pkl (deflated 90%)
#   adding: content/darkroom_normal_1816.pkl (deflated 91%)
#   adding: content/darkroom_normal_1832.pkl (deflated 90%)
#   adding: content/darkroom_normal_1814.pkl (deflated 91%)
#   adding: content/darkroom_normal_1855.pkl (deflated 90%)
#   adding: content/darkroom_normal_1854.pkl (deflated 93%)
#   adding: content/darkroom_normal_1807.pkl (deflated 94%)
#   adding: content/darkroom_normal_1986.pkl (deflated 90%)
#   adding: content/darkroom_normal_1962.pkl (deflated 90%)
#   adding: content/darkroom_normal_1806.pkl (deflated 92%)
#   adding: content/darkroom_normal_1898.pkl (deflated 90%)
#   adding: content/darkroom_normal_1908.pkl (deflated 91%)
#   adding: content/darkroom_normal_1909.pkl (deflated 92%)
#   adding: content/darkroom_normal_1835.pkl (deflated 92%)
#   adding: content/darkroom_normal_1982.pkl (deflated 92%)
#   adding: content/darkroom_normal_1955.pkl (deflated 92%)
#   adding: content/darkroom_normal_1941.pkl (deflated 92%)
#   adding: content/darkroom_normal_1826.pkl (deflated 90%)
#   adding: content/darkroom_normal_1841.pkl (deflated 93%)
#   adding: content/darkroom_normal_1893.pkl (deflated 93%)
#   adding: content/darkroom_normal_1933.pkl (deflated 91%)
#   adding: content/darkroom_normal_1958.pkl (deflated 93%)
#   adding: content/darkroom_normal_1946.pkl (deflated 92%)
#   adding: content/darkroom_normal_1844.pkl (deflated 93%)
#   adding: content/darkroom_normal_1948.pkl (deflated 91%)
#   adding: content/darkroom_normal_1992.pkl (deflated 92%)
#   adding: content/darkroom_normal_1876.pkl (deflated 91%)
#   adding: content/darkroom_normal_1823.pkl (deflated 93%)
#   adding: content/darkroom_normal_1973.pkl (deflated 90%)
#   adding: content/darkroom_normal_1988.pkl (deflated 92%)
#   adding: content/darkroom_normal_1934.pkl (deflated 91%)
#   adding: content/darkroom_normal_1980.pkl (deflated 90%)
#   adding: content/darkroom_normal_1979.pkl (deflated 93%)
#   adding: content/darkroom_normal_1825.pkl (deflated 92%)
#   adding: content/darkroom_normal_1834.pkl (deflated 91%)
#   adding: content/darkroom_normal_1899.pkl (deflated 90%)
#   adding: content/darkroom_normal_1879.pkl (deflated 90%)
#   adding: content/darkroom_normal_1804.pkl (deflated 94%)
#   adding: content/darkroom_normal_1808.pkl (deflated 92%)
#   adding: content/darkroom_normal_1815.pkl (deflated 90%)
#   adding: content/darkroom_normal_1856.pkl (deflated 93%)
#   adding: content/darkroom_normal_1838.pkl (deflated 90%)
#   adding: content/darkroom_normal_1901.pkl (deflated 90%)
#   adding: content/darkroom_normal_1812.pkl (deflated 90%)
#   adding: content/darkroom_normal_1938.pkl (deflated 94%)
#   adding: content/darkroom_normal_1885.pkl (deflated 91%)
#   adding: content/darkroom_normal_1967.pkl (deflated 91%)
#   adding: content/darkroom_normal_1960.pkl (deflated 93%)
#   adding: content/darkroom_normal_1853.pkl (deflated 90%)
#   adding: content/darkroom_normal_1810.pkl (deflated 91%)
#   adding: content/darkroom_normal_1857.pkl (deflated 90%)
#   adding: content/darkroom_normal_1959.pkl (deflated 92%)
#   adding: content/darkroom_normal_1978.pkl (deflated 91%)
#   adding: content/darkroom_normal_1984.pkl (deflated 90%)
#   adding: content/darkroom_normal_1927.pkl (deflated 91%)
#   adding: content/darkroom_normal_1813.pkl (deflated 92%)
#   adding: content/wandb/latest-run/run-muy0qsju.wandb (deflated 79%)
#   adding: content/wandb/run-20240802_093024-3cmzkbfz/ (stored 0%)
#   adding: content/wandb/run-20240802_093024-3cmzkbfz/tmp/ (stored 0%)
#   adding: content/wandb/run-20240802_093024-3cmzkbfz/tmp/code/ (stored 0%)
#   adding: content/wandb/run-20240802_093024-3cmzkbfz/logs/ (stored 0%)
#   adding: content/wandb/run-20240802_093024-3cmzkbfz/logs/debug.log (deflated 79%)
#   adding: content/wandb/run-20240802_093024-3cmzkbfz/files/ (stored 0%)
#   adding: content/wandb/run-20240802_093036-muy0qsju/ (stored 0%)
#   adding: content/wandb/run-20240802_093036-muy0qsju/run-muy0qsju.wandb (deflated 79%)
#   adding: content/wandb/run-20240802_093036-muy0qsju/tmp/ (stored 0%)
#   adding: content/wandb/run-20240802_093036-muy0qsju/tmp/code/ (stored 0%)
#   adding: content/wandb/run-20240802_093036-muy0qsju/logs/ (stored 0%)
#   adding: content/wandb/run-20240802_093036-muy0qsju/logs/debug-internal.log (deflated 96%)
#   adding: content/wandb/run-20240802_093036-muy0qsju/logs/debug.log (deflated 72%)
#   adding: content/wandb/run-20240802_093036-muy0qsju/files/ (stored 0%)
#   adding: content/wandb/run-20240802_093036-muy0qsju/files/requirements.txt (deflated 56%)
#   adding: content/wandb/run-20240802_093036-muy0qsju/files/config.yaml (deflated 65%)
#   adding: content/wandb/run-20240802_093036-muy0qsju/files/wandb-summary.json (deflated 15%)
#   adding: content/wandb/run-20240802_093036-muy0qsju/files/wandb-metadata.json (deflated 55%)
#   adding: content/wandb/run-20240802_093036-muy0qsju/files/output.log (deflated 94%)
#   adding: content/darkroom_normal_1904.pkl (deflated 90%)
#   adding: content/darkroom_normal_1956.pkl (deflated 90%)
#   adding: content/darkroom_normal_1953.pkl (deflated 94%)
#   adding: content/darkroom_normal_1880.pkl (deflated 90%)
#   adding: content/darkroom_normal_1809.pkl (deflated 91%)
#   adding: content/darkroom_normal_1936.pkl (deflated 93%)
#   adding: content/darkroom_normal_1942.pkl (deflated 90%)
#   adding: content/darkroom_normal_1805.pkl (deflated 95%)
#   adding: content/darkroom_normal_1989.pkl (deflated 92%)
#   adding: content/darkroom_normal_1917.pkl (deflated 90%)
#   adding: content/darkroom_normal_1821.pkl (deflated 90%)
#   adding: content/darkroom_normal_1968.pkl (deflated 92%)
#   adding: content/darkroom_normal_1896.pkl (deflated 93%)
#   adding: content/darkroom_normal_1990.pkl (deflated 90%)
#   adding: content/darkroom_normal_1888.pkl (deflated 94%)
#   adding: content/darkroom_normal_1943.pkl (deflated 91%)
#   adding: content/darkroom_normal_1997.pkl (deflated 90%)
#   adding: content/darkroom_normal_1949.pkl (deflated 92%)
#   adding: content/darkroom_normal_1907.pkl (deflated 93%)
#   adding: content/darkroom_normal_1977.pkl (deflated 90%)
#   adding: content/darkroom_normal_1890.pkl (deflated 90%)
#   adding: content/darkroom_normal_1891.pkl (deflated 91%)
#   adding: content/darkroom_normal_1875.pkl (deflated 90%)
#   adding: content/darkroom_normal_1859.pkl (deflated 91%)
#   adding: content/darkroom_normal_1911.pkl (deflated 92%)
#   adding: content/darkroom_normal_1817.pkl (deflated 92%)
#   adding: content/darkroom_normal_1920.pkl (deflated 90%)
#   adding: content/darkroom_normal_1945.pkl (deflated 90%)
#   adding: content/darkroom_normal_1921.pkl (deflated 93%)
#   adding: content/darkroom_normal_1963.pkl (deflated 92%)
#   adding: content/darkroom_normal_1981.pkl (deflated 92%)
#   adding: content/darkroom_normal_1937.pkl (deflated 90%)
#   adding: content/darkroom_normal_1861.pkl (deflated 90%)
#   adding: content/darkroom_normal_1972.pkl (deflated 93%)
#   adding: content/darkroom_normal_1932.pkl (deflated 92%)
#   adding: content/darkroom_normal_1951.pkl (deflated 90%)
#   adding: content/darkroom_normal_1873.pkl (deflated 90%)
#   adding: content/darkroom_normal_1800.pkl (deflated 90%)
#   adding: content/darkroom_normal_1883.pkl (deflated 92%)
#   adding: content/darkroom_normal_1822.pkl (deflated 91%)
#   adding: content/darkroom_normal_1874.pkl (deflated 93%)
#   adding: content/darkroom_normal_1998.pkl (deflated 90%)
#   adding: content/darkroom_normal_1947.pkl (deflated 90%)
#   adding: content/darkroom_normal_1993.pkl (deflated 92%)
#   adding: content/darkroom_normal_1869.pkl (deflated 91%)
#   adding: content/darkroom_normal_1803.pkl (deflated 90%)
#   adding: content/darkroom_normal_1995.pkl (deflated 91%)
#   adding: content/darkroom_normal_1801.pkl (deflated 90%)
#   adding: content/darkroom_normal_1974.pkl (deflated 92%)
#   adding: content/darkroom_normal_1996.pkl (deflated 92%)
#   adding: content/darkroom_normal_1965.pkl (deflated 90%)
#   adding: content/darkroom_normal_1878.pkl (deflated 95%)
#   adding: content/darkroom_normal_1923.pkl (deflated 90%)
#   adding: content/darkroom_normal_1918.pkl (deflated 90%)
#   adding: content/darkroom_normal_1864.pkl (deflated 90%)
#   adding: content/darkroom_normal_1849.pkl (deflated 90%)
#   adding: content/darkroom_normal_1966.pkl (deflated 90%)
#   adding: content/darkroom_normal_1887.pkl (deflated 90%)
#   adding: content/darkroom_normal_1983.pkl (deflated 90%)
#   adding: content/darkroom_normal_1985.pkl (deflated 91%)
#   adding: content/darkroom_normal_1970.pkl (deflated 90%)
#   adding: content/darkroom_normal_1852.pkl (deflated 92%)
#   adding: content/darkroom_normal_1889.pkl (deflated 91%)
#   adding: content/darkroom_normal_1842.pkl (deflated 90%)
#   adding: content/darkroom_normal_1897.pkl (deflated 91%)
#   adding: content/darkroom_normal_1870.pkl (deflated 90%)
#   adding: content/darkroom_normal_1912.pkl (deflated 90%)
#   adding: content/darkroom_normal_1865.pkl (deflated 90%)
#   adding: content/darkroom_normal_1872.pkl (deflated 92%)
#   adding: content/darkroom_normal_1961.pkl (deflated 90%)
#   adding: content/darkroom_normal_1964.pkl (deflated 90%)
#   adding: content/darkroom_normal_1850.pkl (deflated 91%)
#   adding: content/darkroom_normal_1952.pkl (deflated 92%)
#   adding: content/darkroom_normal_1892.pkl (deflated 90%)
#   adding: content/darkroom_normal_1971.pkl (deflated 90%)
#   adding: content/darkroom_normal_1877.pkl (deflated 90%)
#   adding: content/darkroom_normal_1987.pkl (deflated 90%)
#   adding: content/darkroom_normal_1830.pkl (deflated 93%)
#   adding: content/darkroom_normal_1811.pkl (deflated 91%)
#   adding: content/darkroom_normal_1863.pkl (deflated 92%)
#   adding: content/darkroom_normal_1929.pkl (deflated 92%)
#   adding: content/darkroom_normal_1916.pkl (deflated 92%)
#   adding: content/darkroom_normal_1871.pkl (deflated 94%)
#   adding: content/darkroom_normal_1824.pkl (deflated 91%)
#   adding: content/darkroom_normal_1851.pkl (deflated 92%)
#   adding: content/darkroom_normal_1882.pkl (deflated 90%)
#   adding: content/darkroom_normal_1935.pkl (deflated 90%)
#   adding: content/darkroom_normal_1928.pkl (deflated 90%)
#   adding: content/darkroom_normal_1919.pkl (deflated 90%)
#   adding: content/darkroom_normal_1957.pkl (deflated 90%)
#   adding: content/darkroom_normal_1944.pkl (deflated 90%)
#   adding: content/darkroom_normal_1819.pkl (deflated 93%)
#   adding: content/darkroom_normal_1930.pkl (deflated 90%)
#   adding: content/darkroom_normal_1954.pkl (deflated 90%)
#   adding: content/darkroom_normal_1847.pkl (deflated 90%)
#   adding: content/darkroom_normal_1866.pkl (deflated 93%)
#   adding: content/darkroom_normal_1881.pkl (deflated 91%)
#   adding: content/darkroom_normal_1969.pkl (deflated 91%)
#   adding: content/darkroom_normal_1848.pkl (deflated 90%)
#   adding: content/darkroom_normal_1925.pkl (deflated 90%)
#   adding: content/darkroom_normal_1905.pkl (deflated 93%)
#   adding: content/darkroom_normal_1829.pkl (deflated 94%)
#   adding: content/darkroom_normal_1860.pkl (deflated 91%)
#   adding: content/darkroom_normal_1831.pkl (deflated 91%)
#   adding: content/darkroom_normal_1994.pkl (deflated 90%)
#   adding: content/darkroom_normal_1839.pkl (deflated 92%)
#   adding: content/darkroom_normal_1924.pkl (deflated 91%)
#   adding: content/darkroom_normal_1895.pkl (deflated 90%)
#   adding: content/darkroom_normal_1843.pkl (deflated 90%)
#   adding: content/darkroom_normal_1976.pkl (deflated 90%)
#   adding: content/darkroom_normal_1894.pkl (deflated 92%)
#   adding: content/darkroom_normal_1975.pkl (deflated 92%)
#   adding: content/darkroom_normal_1906.pkl (deflated 92%)
#   adding: content/darkroom_normal_1845.pkl (deflated 90%)
#   adding: content/darkroom_normal_1999.pkl (deflated 93%)
#   adding: content/darkroom_normal_1903.pkl (deflated 93%)
#   adding: content/darkroom_normal_1900.pkl (deflated 90%)

# %%
from google.colab import files
files.download('/content/all_files.zip')
